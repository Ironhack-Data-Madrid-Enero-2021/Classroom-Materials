# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
titanic.select_dtypes(np.number).columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
#your code here- categorical variable
titanic.select_dtypes(object).columns
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
plt.style.use('classic')
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
titanic['Age'].hist()

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
plt.style.use('classic')
plt.figure(figsize=(12,6))
for i in range(3):
    bins=[10, 20, 50]
    plt.subplot(1, 3, i+1)
    titanic['Age'].hist(bins=bins[i])

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here
#La seleccion bins afecta al plot en su resolucion, en su numero de barras.
#Se podria tener una sola, lo cual no diria nada, o tenerlo por año por de edad.

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
sns.distplot(titanic['Age'])
plt.title('Age distribution',size=12,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Age distribution')

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
y=titanic['Gender'].value_counts()
print (y)
plt.bar(['Male','Female'], y, color=['b', 'r'])
plt.ylabel('Gender')
plt.title('Gender',size=12,fontweight='bold')
# Out:
# male      843
# female    466
# Name: Gender, dtype: int64
# Text(0.5, 1.0, 'Gender')

# %%
# your code here- 2nd way
sns.barplot((['Male','Female']), y)
plt.title('Gender',size=12,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Gender')

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here
y=titanic['Pclass'].value_counts().sort_index()
plt.bar(['1','2','3'], y, color=['r', 'g', 'b'])
plt.ylabel('Pclass')
plt.title('Pclass',size=12,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Pclass')

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
print (titanic['Age'].describe())
plt.figure(figsize=(12,6))
plt.bar(1, titanic['Age'].describe()[1], 0.15, yerr=titanic['Age'].describe()[2])
plt.bar(0, 0, 0.15)
plt.bar(2, 0, 0.15)
plt.title('Age mean and std',size=12,fontweight='bold')
plt.figure(figsize=(12,6))
y=[titanic['Age'].describe()[4],titanic['Age'].describe()[5],titanic['Age'].describe()[6]]
x=['25%', '50%', '75%']
plt.bar(x,y, color=['g', 'b','r'])
plt.title('Percentile',size=12,fontweight='bold')
plt.ylabel('Age')
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64
# Text(0, 0.5, 'Age')

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here
'''
Lo primero que se observa es que la edad media ronda los 30 años. 
Por otro lado la desviacion estandar es casi la mitad de la media,
por lo que hay personas de muy corta edad y/o ancianos.
En el segundo plot se muestran los percentiles, la mayor parte de la poblacion esta
concentrada en un rango de edad entre los 20 y los 35 años.
'''
# Out:
# '\nLo primero que se observa es que la edad media ronda los 30 años. \nPor otro lado la desviacion estandar es casi la mitad de la media,\npor lo que hay personas de muy corta edad y/o ancianos.\nEn el segundo plot se muestran los percentiles, la mayor parte de la poblacion esta\nconcentrada en un rango de edad entre los 20 y los 35 años.\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here
sns.distplot(titanic['Age'])
plt.title('Age',size=12,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Age')

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here
#Podria decirse que aproximadamente la edad de las personas en el barco sigue una distribucion normal

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
plt.scatter(titanic['Age'], titanic['Fare'])
plt.title('Fare vs Age',size=12,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Fare vs Age')

# %%
# your code-2nd way
sns.regplot(x="Age", y="Fare", data=titanic);
plt.title('Fare vs Age',size=12,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Fare vs Age')

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here
mask=np.zeros_like(titanic.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)]=True
cmap=sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(titanic.corr(), mask=mask, cmap=cmap, vmax=1.0, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.xticks(rotation=45)
plt.title("Correlation")
# Out:
# Text(0.5, 1.0, 'Correlation')

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here
#Parch con SibSp

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
sns.boxplot(x='Pclass',y='Age',data=titanic)

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
sns.FacetGrid(data=titanic,col='Gender').map(plt.hist,'Age')
