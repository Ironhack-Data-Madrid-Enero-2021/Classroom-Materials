# %% [markdown]
# # Time Series
# ![](https://i.ytimg.com/vi/coMhteW-sLU/maxresdefault.jpg)

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#What-is-a-time-series?" data-toc-modified-id="What-is-a-time-series?-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>What is a time series?</a></span></li><li><span><a href="#Time-Series-Analysis" data-toc-modified-id="Time-Series-Analysis-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Time Series Analysis</a></span><ul class="toc-item"><li><span><a href="#Motivation" data-toc-modified-id="Motivation-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Motivation</a></span></li><li><span><a href="#Time-intervals" data-toc-modified-id="Time-intervals-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Time intervals</a></span></li><li><span><a href="#Pandas-DateTime-Range" data-toc-modified-id="Pandas-DateTime-Range-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Pandas DateTime Range</a></span></li></ul></li><li><span><a href="#Exploratory-Analysis" data-toc-modified-id="Exploratory-Analysis-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Exploratory Analysis</a></span><ul class="toc-item"><li><span><a href="#Moving-Average" data-toc-modified-id="Moving-Average-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Moving Average</a></span></li></ul></li><li><span><a href="#Decomposing-a-time-series" data-toc-modified-id="Decomposing-a-time-series-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Decomposing a time series</a></span><ul class="toc-item"><li><span><a href="#Trend" data-toc-modified-id="Trend-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Trend</a></span></li><li><span><a href="#Seasonality" data-toc-modified-id="Seasonality-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Seasonality</a></span></li><li><span><a href="#Cycles" data-toc-modified-id="Cycles-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Cycles</a></span></li><li><span><a href="#Residuals" data-toc-modified-id="Residuals-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Residuals</a></span></li></ul></li><li><span><a href="#Stationarity" data-toc-modified-id="Stationarity-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Stationarity</a></span><ul class="toc-item"><li><span><a href="#Augmented-Dickey-Fuller-test" data-toc-modified-id="Augmented-Dickey-Fuller-test-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Augmented Dickey Fuller test</a></span></li></ul></li><li><span><a href="#Auto-Correlation-Function" data-toc-modified-id="Auto-Correlation-Function-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Auto Correlation Function</a></span><ul class="toc-item"><li><span><a href="#Lag-Plot" data-toc-modified-id="Lag-Plot-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Lag Plot</a></span></li></ul></li><li><span><a href="#Partial-Auto-Correlation-Function" data-toc-modified-id="Partial-Auto-Correlation-Function-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Partial Auto Correlation Function</a></span></li><li><span><a href="#Differenciating" data-toc-modified-id="Differenciating-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Differenciating</a></span></li><li><span><a href="#ARIMA" data-toc-modified-id="ARIMA-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>ARIMA</a></span><ul class="toc-item"><li><span><a href="#AR(p)" data-toc-modified-id="AR(p)-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>AR(p)</a></span></li><li><span><a href="#I(d)" data-toc-modified-id="I(d)-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>I(d)</a></span></li><li><span><a href="#MA(q)" data-toc-modified-id="MA(q)-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>MA(q)</a></span></li></ul></li><li><span><a href="#Step-by-Step" data-toc-modified-id="Step-by-Step-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Step by Step</a></span><ul class="toc-item"><li><span><a href="#I(d):-Differencing" data-toc-modified-id="I(d):-Differencing-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>I(d): Differencing</a></span></li><li><span><a href="#MA(q)" data-toc-modified-id="MA(q)-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>MA(q)</a></span></li><li><span><a href="#AR(p)" data-toc-modified-id="AR(p)-10.3"><span class="toc-item-num">10.3&nbsp;&nbsp;</span>AR(p)</a></span></li><li><span><a href="#ARIMA" data-toc-modified-id="ARIMA-10.4"><span class="toc-item-num">10.4&nbsp;&nbsp;</span>ARIMA</a></span></li></ul></li><li><span><a href="#Further-Resources" data-toc-modified-id="Further-Resources-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Further Resources</a></span></li></ul></div>

# %% [markdown]
# ## What is a time series?
# >A time series is a series of data points indexed in time order. Most commonly, a time series is a sequence taken at successive equally spaced points in time. Thus it is a sequence of [discrete](https://en.wikipedia.org/wiki/Continuous_or_discrete_variable)-time data.
#
# _Source: [Wikipedia](https://en.wikipedia.org/wiki/Time_series)_
#
# **Examples:**
# - Stock Prices
# - Weather data (temperature, humidity, etc..)
# - Visitor to a webpage, Youtube views
# - Power generation
# - Audio
# - Video
#
# ## Time Series Analysis
# ### Motivation
# - **Forecasting** (Predicting)
# - Signal Processing
# - Pattern Recognition and Anomaly Detection

# %% [markdown]
# ### Time intervals
# When studying a time-series, the frequency (intervals) in which the data is colected is very important.
#
# Luckly, pandas has a couple of tools to help us out with it.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Pandas DateTime Range
# ```python
# pd.date_range(start, end, periods, freq)
# ```
# Of these 4 parameters, you must pass 3.

# %%
pd.date_range("18/02/2021", periods=7, freq="D")
# Out:
# DatetimeIndex(['2021-02-18', '2021-02-19', '2021-02-20', '2021-02-21',
#                '2021-02-22', '2021-02-23', '2021-02-24'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# **Frequency Aliases**
#
# Some of the most common are:
#
# - "D" : Day
# - "W" : Week
# - "H" : Hour
# - "T" : Minute
# - "S" : Second
# - "L" : Milisecond
#
# Of course, there are many [more](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#timeseries-offset-aliases).

# %%
pd.date_range("18/02/2021","25/02/2021",periods=8)
# Out:
# DatetimeIndex(['2021-02-18', '2021-02-19', '2021-02-20', '2021-02-21',
#                '2021-02-22', '2021-02-23', '2021-02-24', '2021-02-25'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# If we do not define the frequency beforehand, we can infer it!
#
# It will be used when setting the dates as the index for our data.

# %%
dates = pd.date_range("18/02/2021","18/03/2021",periods=29)
freq = pd.infer_freq(dates)
print(freq)
# Out:
# D

# %%
dates.freq = freq

# %%
dates
# Out:
# DatetimeIndex(['2021-02-18', '2021-02-19', '2021-02-20', '2021-02-21',
#                '2021-02-22', '2021-02-23', '2021-02-24', '2021-02-25',
#                '2021-02-26', '2021-02-27', '2021-02-28', '2021-03-01',
#                '2021-03-02', '2021-03-03', '2021-03-04', '2021-03-05',
#                '2021-03-06', '2021-03-07', '2021-03-08', '2021-03-09',
#                '2021-03-10', '2021-03-11', '2021-03-12', '2021-03-13',
#                '2021-03-14', '2021-03-15', '2021-03-16', '2021-03-17',
#                '2021-03-18'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# **Let's mock up some data**

# %%
len(dates)
# Out:
# 29

# %%
df = pd.DataFrame(index=dates)
df["values"] = np.random.randint(500, 3000, len(dates))
df.head()
# Out:
#             values
# 2021-02-18    1541
# 2021-02-19    2708
# 2021-02-20    2024
# 2021-02-21    2521
# 2021-02-22    2728

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Of course, not all real world data is this random.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/a10.csv')
df.head()
# Out:
#          date     value
# 0  1991-07-01  3.526591
# 1  1991-08-01  3.180891
# 2  1991-09-01  3.252221
# 3  1991-10-01  3.611003
# 4  1991-11-01  3.565869

# %%
df.index = pd.to_datetime(df["date"])

# %%
df.index
# Out:
# DatetimeIndex(['1991-07-01', '1991-08-01', '1991-09-01', '1991-10-01',
#                '1991-11-01', '1991-12-01', '1992-01-01', '1992-02-01',
#                '1992-03-01', '1992-04-01',
#                ...
#                '2007-09-01', '2007-10-01', '2007-11-01', '2007-12-01',
#                '2008-01-01', '2008-02-01', '2008-03-01', '2008-04-01',
#                '2008-05-01', '2008-06-01'],
#               dtype='datetime64[ns]', name='date', length=204, freq=None)

# %% [markdown]
# And after infering the frequency

# %%
df.index.freq = pd.infer_freq(df.index)
df.index
# Out:
# DatetimeIndex(['1991-07-01', '1991-08-01', '1991-09-01', '1991-10-01',
#                '1991-11-01', '1991-12-01', '1992-01-01', '1992-02-01',
#                '1992-03-01', '1992-04-01',
#                ...
#                '2007-09-01', '2007-10-01', '2007-11-01', '2007-12-01',
#                '2008-01-01', '2008-02-01', '2008-03-01', '2008-04-01',
#                '2008-05-01', '2008-06-01'],
#               dtype='datetime64[ns]', name='date', length=204, freq='MS')

# %%
df.plot(figsize=(15,6), title="Sales of anti-diabetic drugs in Australia");

# %% [markdown]
# ## Exploratory Analysis
#
# We begin seeing some patterns and characteristics on our data.
#
# Let's check out the average of our values.

# %%
df.plot(figsize=(15,6))
plt.title("Sales of anti-diabetic drugs in Australia")
plt.axhline(df.value.mean(), c="g", label="mean")
plt.legend();

# %% [markdown]
# ### Moving Average
#
# **Rolling Window**
#
# The average of all values does not tells us much, but let's se how that average behaves through time.

# %%
df.rolling(window=12)
# Out:
# Rolling [window=12,center=False,axis=0]

# %%
plt.figure(figsize=(15,6))
plt.title("Sales of anti-diabetic drugs in Australia")

plt.plot(df["value"], label="value")

#plt.axhline(df.value.mean(), c="g", label="mean")

# We use the `.rolling` method to define windows in which the the average is calculated.
plt.plot(df.rolling(window=12).mean(), label="rolling window")

plt.legend();

# %% [markdown]
# As you can see, there are no values for the average on the 12 first points, because there is no window from previous 12 values there.
#
# ![](https://i.stack.imgur.com/Xd62a.png)

# %% [markdown]
# Let's try a different way of calculating a Moving Average.
#
# Instead of keeping a fix size window and moving it, we can try increasing the size of our window each time we move forward.
#
# **Expanding Window**

# %%
plt.figure(figsize=(15,6))
plt.title("Sales of anti-diabetic drugs in Australia")

plt.plot(df["value"], label="value")

#plt.axhline(df.value.mean(), c="g", label="mean")

#plt.plot(df.rolling(window=12).mean(), label="rolling window")

plt.plot(df.expanding().mean(), c="purple", label="expanding window")

plt.legend();

# %% [markdown]
# ![](https://i.stack.imgur.com/Zs2Xp.png)

# %% [markdown]
# Either way we look at it, we can see a tendency that the sales increase over time.
#
# ## Decomposing a time series
# There are `four` components for a time series.
#
# If we separate the different components of a time series, the way the average changes through time is called the `trend` and it represents the way values behave on a "long term" perspective.
#
# ### Trend
# How the average changes through time.
# On our example, there is a clear increasing trend.
#
# Not all time series are like that.
#
# Time series whose average doesn't change through time are called `stationary`. More on stationarity later.
#
# The trend, however, does not account for all the changes in our data. There are ups and downs that repeat in some patterns. This can be attributed to one of two things.
#
# ### Seasonality
# Patterns of peaks and droughts that repeat within a regular interval are attributed to `seasons`. These intervals usually relate to a time pattern of the calendar (yearly, bi-yearly, monthly, daily, weekly, hourly, etc.)
#
# ### Cycles
# Patterns repeated in uneven intervals or that do not relate to a period of the calendar.
#
# In general, they have a longer interval than seasons and a larger amplitude of variation.
#
# Therefore, cycles are more difficult to predict than seasons. (Remember that real world data are susceptible to a lot of unpredictable influences)
#
# ### Residuals
# Variations that do not repeat in any sort of pattern are called `residuals` or `noise`.
#
#
# Let's se a tool to decompose our data.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
res = seasonal_decompose(df.value, model="additive")
res.plot();

# %%
plt.figure(figsize=(15,6))
plt.title("Sales of anti-diabetic drugs in Australia")

plt.plot(df["value"], label="value")

plt.plot(res.trend, label="trend")

plt.plot(res.seasonal, label="seasonal")

plt.legend();

# %% [markdown]
# It is called an `additive` model because if you sum the parts up, you get the original data back.

# %%
plt.figure(figsize=(15,6))
plt.title("Sales of anti-diabetic drugs in Australia")
plt.plot(df["value"], label="value")
plt.plot(res.trend + res.seasonal + res.resid, label="reconstructed")
plt.legend();

# %%
x = np.linspace(0,8*np.pi,49)
# np.sin takes an angle in radian.
# 360° == 2π rad
y = np.sin(x) + 1

# %%
sin = pd.DataFrame(y, index=pd.date_range("01/01/2021", periods=49, freq="MS"))

# %%
plt.figure(figsize=(12,5))
plt.plot(sin)

# %%
sin.index
# Out:
# DatetimeIndex(['2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01', '2023-07-01', '2023-08-01',
#                '2023-09-01', '2023-10-01', '2023-11-01', '2023-12-01',
#                '2024-01-01', '2024-02-01', '2024-03-01', '2024-04-01',
#                '2024-05-01', '2024-06-01', '2024-07-01', '2024-08-01',
#                '2024-09-01', '2024-10-01', '2024-11-01', '2024-12-01',
#                '2025-01-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
seasonal_decompose(sin).plot();

# %% [markdown]
# ## Stationarity
#
# - **Stationary**
#
# Mean is constant over time (there is no trend)
#
# Variance is constant
#
# - **Weakly stationary**
#
# No trend
#
# Variance is not constant
#
# - **Non-Stationary**
#
# There is a trend, ascending or descending
#
# ----
#
# Sometimes it is not very clear to see if there is a clear trend or not, therefore we can use a statistical test to check whether or not a series is Stationary.
#
# ### Augmented Dickey Fuller test
#
# When doing a statistical test, we have a null hypothesis and an alternative hypothesis and we check some test statistic against critical values to see whether we keep the null hypothesis or reject it and accept the alternative.
#
# - $H_0$ (Null Hypothesis) : The series is **not** stationary and there is a statistical significant trend
#
# - $H_A$ (Alternative Hypothesis) : The series is Stationary

# %%
from statsmodels.tsa.stattools import adfuller
res = adfuller(df["value"])
res
# Out:
# (3.1451856893067434,
#  1.0,
#  15,
#  188,
#  {'1%': -3.465620397124192,
#   '5%': -2.8770397560752436,
#   '10%': -2.5750324547306476},
#  549.6705685364172)

# %% [markdown]
# As we can see, there are a lot of different values resulting from our test. Lets separate them to look at the part that matters to us.

# %%
adf, pvalue, usedlag, nobs, critical_values, icbest = res

# %%
# Our test statistic
adf
# Out:
# 3.1451856893067434

# %%
# The critical values for different confidence intervals (How strict we are)
critical_values
# Out:
# {'1%': -3.465620397124192,
#  '5%': -2.8770397560752436,
#  '10%': -2.5750324547306476}

# %%
res = adfuller(sin)
res
# Out:
# (-27153662497.998405,
#  0.0,
#  3,
#  361,
#  {'1%': -3.4485948978753314,
#   '5%': -2.86957971128312,
#   '10%': -2.571053050314224},
#  -18257.744749529465)

# %% [markdown]
# Since our adf is greater than any of the critical values, we cannot reject the null hypothesis.
#
# Therefore, as previously seen, even on a 1% confidence level, we can affirm that our data is `not` stationary.
#
# > Alternatively, we can look at the p-value and compare it with a predefine confidence interval alpha (usually 5%).
# >
# > If p_value > alpha (0.05), we cannot reject the null hypothesis.

# %% [markdown]
# ## Auto Correlation Function
# In the broadest sense [correlation](https://en.wikipedia.org/wiki/Correlation_and_dependence) is any statistical association, though it commonly refers to the degree to which a pair of variables are linearly related.
#
# [Autocorrelation](https://en.wikipedia.org/wiki/Autocorrelation), also known as serial correlation, is the correlation of a signal with a delayed copy of itself as a function of delay.
#
# We can have an idea of autocorrelation by looking at a lag plot.

# %%
data_t = df["value"][:-1]
data_t_plus_1 = df["value"][1:]
plt.figure(figsize=(5,5))
plt.plot(data_t[:10].values, label="y(t)")
plt.plot(data_t_plus_1[:10].values, label="y(t+1)")
plt.legend();

# %% [markdown]
# ### Lag Plot

# %%
x = np.linspace(0,1,100)
y = 0.5*x
plt.plot(y)

# %%
lag = 10
y_t = y[lag:]
y_plus = y[:-lag]
plt.figure(figsize=(5,5))
plt.scatter(y_t,y=y_plus)
plt.xlabel("y(t)")
plt.ylabel(f"y(t+{lag})");

# %% [markdown]
# $y = f(x) = mx + b$

# %%
x = np.linspace(0,1,100)
y = .5*x
y[-50:] -= .5
plt.plot(y)

# %%
lag = 1
y_t = y[lag:]
y_plus = y[:-lag]
plt.figure(figsize=(5,5))
plt.scatter(y_t,y=y_plus)
plt.xlabel("y(t)")
plt.ylabel(f"y(t+{lag})");

# %%
x = np.linspace(0,10,100)
y = np.sin(x)
plt.plot(y)

# %%
data_t = y[:-1]
data_t_plus_1 = y[1:]
plt.figure(figsize=(5,5))
plt.plot(data_t, label="y(t)")
plt.plot(data_t_plus_1, label="y(t+1)")
plt.legend();

# %%
lag = 1
y_t = y[lag:]
y_plus = y[:-lag]
plt.figure(figsize=(5,5))
plt.scatter(y_t,y=y_plus)
plt.xlabel("y(t)")
plt.ylabel(f"y(t+{lag})");

# %% [markdown]
# **Regression Signal vs Time**

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(np.expand_dims(x,-1),y)
y_pred = lr.predict(np.expand_dims(x,-1))

plt.plot(y)
plt.plot(y_pred)

# %% [markdown]
# **Regression Signal f(t) vs f(t+1)**

# %%
y_t = y[1:]
y_plus = y[:-1]

plt.figure(figsize=(5,5))
plt.scatter(y_t,y=y_plus)
plt.xlabel("y(t)")
plt.ylabel(f"y(t+{lag})")

lr = LinearRegression()
lr.fit(np.expand_dims(y_t,-1),y_plus)
y_pred = lr.predict(np.expand_dims(y_t,-1))

plt.plot(y[1:],y_pred,c="red")

# %%
lr.predict([[-1]])
# Out:
# array([-0.98085534])

# %%
y_pred = lr.predict(np.expand_dims(y,-1))
plt.plot(x,y)
plt.plot(x,y_pred)

# %%
data_t = df["value"][:-1]
data_t_plus_1 = df["value"][1:]
plt.plot(df["value"])

# %%
data_t = df["value"][:-1]
data_t_plus_1 = df["value"][1:]
plt.figure(figsize=(5,5))
plt.scatter(x=data_t,y=data_t_plus_1)
plt.xlabel("y(t)")
plt.ylabel("y(t+1)")
plt.plot([0, 1], [0, 1], ls="--", c="r", transform=plt.gca().transAxes);
## Alternatively
## pd.plotting.lag_plot(data_t)

# %% [markdown]
# **Linear Regression Sales vs time**

# %%
lr = LinearRegression()
lr.fit(df.index.astype(int).to_frame(),df["value"])
y_pred = lr.predict(df.index.astype(int).to_frame())

plt.plot(df["value"])
plt.plot(df.index,y_pred)

# %%
from sklearn.metrics import mean_squared_error as mse
mse(y_pred,df["value"])
# Out:
# 5.119882462136236

# %% [markdown]
# **Linear Regression Sales y(t) vs y(t-1)**

# %%
lr = LinearRegression()
data_t = df["value"][:-1]
data_t_plus_1 = df["value"][1:]
lr.fit(data_t.to_frame(),data_t_plus_1)
y_pred = lr.predict(data_t.to_frame())

plt.figure(figsize=(5,5))
plt.scatter(x=data_t,y=data_t_plus_1)
plt.plot(data_t,y_pred, c="r")
plt.xlabel("y(t)")
plt.ylabel("y(t+1)")
# Out:
# Text(0, 0.5, 'y(t+1)')

# %%
plt.plot(df["value"])
plt.plot(df.index[1:],y_pred)

# %%
### Separating test data
lr = LinearRegression()
## Test Data
y_true = df["value"][-10:]
# Traning Data
data_t = df["value"][:-11]
data_t_plus_1 = df["value"][1:-10]
# Training model
lr.fit(data_t.to_frame(),data_t_plus_1)
# Out:
# LinearRegression()

# %%
previous = [[data_t[-1]]]
y_pred = []
for _ in range(10):
    predict = lr.predict(previous)[0]
    y_pred.append(predict)
    previous = [[predict]]

# %%
y_pred
# Out:
# [21.11605676760367,
#  20.44720590762727,
#  19.82486201375939,
#  19.245791333864766,
#  18.70698496713144,
#  18.20564322956463,
#  17.73916110658907,
#  17.305114717170344,
#  16.901248719121575,
#  16.52546459015241]

# %%
plt.plot(data_t)
plt.plot(df.index[-10:],y_pred)
plt.plot(y_true)

# %%
mse(y_pred,y_true)
# Out:
# 29.419916699446453

# %% [markdown]
# The closer it looks to a perfect diagonal, the higher the autocorrelation.
#
# We can measure the value with `np.corrcoef`

# %%
np.corrcoef(data_t,data_t_plus_1)
# Out:
# array([[1.        , 0.91740643],
#        [0.91740643, 1.        ]])

# %%
np.corrcoef(data_t,data_t_plus_1)[0][1]
# Out:
# 0.9174064324470301

# %% [markdown]
# We have however only checked the correlation with the previous value, how would it be with `t+2`?

# %%
def autocorr(data, lag):
    # Slice the relevant subseries based on the lag
    y_minus = data[:(len(data)-lag)]
    y = data[lag:]
    # Subtract the subseries means
    sum_product = np.sum((y_minus-np.mean(y_minus))*(y-np.mean(y)))
    # Normalize with the subseries stds
    return sum_product / (len(y) * np.std(y_minus) * np.std(y))

# %%
ac = [autocorr(df["value"],i) for i in range(1,25)]

# %%
plt.stem(range(1,25),ac)
plt.ylabel("Autocorrelation (t-n)")
plt.xlabel("n");

# %% [markdown]
# **Using Statsmodels**

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
plot_acf(df["value"]);

# %% [markdown]
# ## Partial Auto Correlation Function
# However, if we look at the previous lagplot, we see there isn't a perfect linear correlation. Let's look at those residuals.

# %%
data_t = df["value"][:-1]
data_t_plus_1 = df["value"][1:]
plt.figure(figsize=(5,5))
plt.scatter(x=data_t,y=data_t_plus_1)
plt.xlabel("y(t)")
plt.ylabel("y(t+1)")
plt.plot([0, 1], [0, 1], ls="--", c="r", transform=plt.gca().transAxes);

# %%
lr = LinearRegression()
lr.fit(X=data_t.to_frame(),y=data_t_plus_1);
y_pred = lr.predict(data_t.to_frame())

# %%
plt.figure(figsize=(5,5))
plt.scatter(data_t,data_t_plus_1)
plt.xlabel("y(t)")
plt.ylabel("y(t+1)")
#plt.plot([0, 1], [0, 1], ls="--", c="r", transform=plt.gca().transAxes)
plt.plot(data_t,y_pred, c="orange");

# %%
residuals = data_t_plus_1 - y_pred

# %%
plt.figure(figsize=(5,5))
plt.xlabel("y(t)")
plt.ylabel("residuals")
plt.plot([0, 1], [0, 1], ls="--", c="r", transform=plt.gca().transAxes)
plt.scatter(data_t_plus_1,residuals);

# %%
np.corrcoef(data_t_plus_1,residuals)[0][1]
# Out:
# 0.37036216256264864

# %%
from statsmodels.graphics.tsaplots import plot_pacf

# %%
plot_pacf(df["value"]);

# %% [markdown]
# ## Differenciating

# %%
plt.figure(figsize=(15,6))
plt.title("Monthly anti-diabetic drug sales in Australia")
plt.plot(df["value"], label="value");

# %%
df["difference"] = None
df.iloc[1:,-1] = df["value"][1:].values-df["value"][:-1].values
plt.figure(figsize=(15,6))
plt.title("First difference")
plt.plot(df["difference"]);

# %%
plot_acf(df["value"].diff()[1:]);

# %% [markdown]
# Alternatively, we can use the `.diff()` method.

# %%
plt.figure(figsize=(15,6))
plt.title("Second difference")
plt.plot(df["value"].diff(2));

# %% [markdown]
# ## ARIMA
# ```
# Auto
# Regressive
# ```
# ```
# Integrated
# ```
# ```
# Moving
# Average
# ```
#
# As previously seen, we must consider a lot of different characteristics of our signal before trying to model it. But we're finally ready for it.

# %% [markdown]
# **ARIMA**
#
# Our model, ARIMA, is acctually composed of 3 parts: **AR, I, MA*.
#
# And we can use any of those separately if the order parameter for the other two are 0.
#
# So we build our model using only the parts we need.
#
# The 3 parameters that compose the order of our ARIMA model are:
#
# **order = (p,d,q)**
#
# Each relates to it's own part of the model and each of these relates to the 3 operations we've seen previously. We will use these operations to identify the order of the corresponding model:
#
# ### AR(p)
# > Partial AutoCorrelation Function
#
# The number n of lags that fall outside of the critical zone.
#
# ### I(d)
# > Difference
#
# It refers to the order of differantiation you had to do in order for the series to become stationary.
#
# ### MA(q)
# > AutoCorrelation Function
#
# The number n of lags that fall outside of the critical zone.

# %% [markdown]
# ## Step by Step

# %%
# This is pretty much all we will need
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# %%
## Load data and see it.
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/a10.csv',
                parse_dates=["date"], index_col="date")
                # If date index are parseable, you can do it directly when reading it.

# %%
plt.plot(df);

# %%
# We set aside the final part of our data as test data, and the most part as train.
y_test = df["value"][-15:]
y_train = df["value"][:-15]

# %%
# Agumented Dickey Fuler test
adfuller(y_train)
# Out:
# (2.9655893274570784,
#  1.0,
#  14,
#  174,
#  {'1%': -3.4685016947910636,
#   '5%': -2.8782983668563396,
#   '10%': -2.57570415906989},
#  407.9146036218434)

# %% [markdown]
# Series is definitely not stationary, plus...

# %%
plot_acf(y_train);

# %% [markdown]
# There are a LOT (>10) of positive over limit auto correlations.
#
# Both these are indicative that our data needs some differencing.
#
# ### I(d): Differencing

# %%
for i in range(1,3):
    diff = df["value"].diff(i)[i:]
    plt.figure(figsize=(15,4))
    plt.subplot(1,2,1)
    plt.plot(diff);
    plt.title(f"{i} Difference")
    ax = plt.subplot(1,2,2)
    plot_acf(diff, ax=ax);

# %% [markdown]
# A model with no orders of differencing assumes that the original series is stationary.
#
# A model with one order of differencing assumes that the original series has a constant average trend.
#
# A model with two orders of total differencing assumes that the original series has a time-varying trend.
#
# In this case, we should probably set `d=2`.

# %%
data = df["value"].diff(2)[2:]
# Our data is weakly stationary now
adfuller(first_diff)
# Out:
# (-2.49546283529504,
#  0.11658217250240738,
#  14,
#  187,
#  {'1%': -3.465811691080702,
#   '5%': -2.877123351472649,
#   '10%': -2.5750770662586864},
#  542.6208199775967)

# %% [markdown]
# ### MA(q)
#
# We use the AutoCorrelation (after differencing) to chose which order to use.
# Since only the first 2 lags are over the significance limit, we will keep these ones and set `q=2`.
#
# > Notice there are HUGE correlation values on lags -12 and -24.
# >
# > This indicates a very strong seasonal component!
# >
# > We will deal with these later.

# %%
plot_acf(data);

# %% [markdown]
# ### AR(p)
#
# We use the Partial AutoCorrelation (after differencing) to chose which order to use.
# Since only the first 2 lags are over the significance limit, we will keep these ones and set `p=2`.
#
# > Notice that the same happens here and there is a HUGE partial correlation values on lags -24.
# >
# > This indicates a very strong seasonal component!
# >
# > We will deal with these later as well.

# %%
plot_pacf(data);
# Out:
# /Users/felipe/miniforge3/envs/ironhack/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1434: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %% [markdown]
# ### ARIMA
# Now that we have the all the three parameters, we can create our model.

# %%
order = (2,2,2)
arima = ARIMA(y_train,order=order, freq="MS")
arima;
# Out:
# /Users/felipe/miniforge3/envs/ironhack/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'

# %%
arima = arima.fit()

# %%
### arima.predict(index of first predicted point, index of last predicted point)
y_pred = arima.predict(len(y_train),len(y_train)+14)

# %%
plt.plot(y_train)
plt.plot(y_pred)

# %%
plt.plot(y_test)
plt.plot(y_pred)

# %%
mean_squared_error(y_pred, y_test)
# Out:
# 17.59569583225385

# %% [markdown]
# Not a very good result...
#
# Remember those seasonal relevant values?

# %%
order = (10,2,12)
arima = ARIMA(y_train,order=order, freq="MS")
arima = arima.fit()
y_pred = arima.predict(len(y_train),len(y_train)+14)
plt.plot(y_train)
plt.plot(y_pred)
# Out:
# /Users/felipe/miniforge3/envs/ironhack/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/felipe/miniforge3/envs/ironhack/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /Users/felipe/miniforge3/envs/ironhack/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
plt.plot(y_test)
plt.plot(y_pred)

# %%
mean_squared_error(y_pred, y_test)
# Out:
# 11.666166964436668

# %% [markdown]
# Looks better, right?
#
# But there could be a lot of other problems from creating models with such high order, such as overfitting.
#
# We could better try adding the seasonality into the mix and use a [SARIMAX](https://www.statsmodels.org/stable/generated/statsmodels.tsa.statespace.sarimax.SARIMAX.html) model, which contains it's own order for seasonality.

# %% [markdown]
# ## Further Resources
# - [Detailed step by step recognition of model](https://people.duke.edu/~rnau/arimrule.htm)
# - [Detailed step by step of time series exploration](https://www.machinelearningplus.com/time-series/time-series-analysis-python/)
# - [Detailed step by step of ARIMA model](https://www.machinelearningplus.com/time-series/arima-model-time-series-forecasting-python/)
