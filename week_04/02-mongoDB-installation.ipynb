# %% [markdown]
# # MongoDB
#
# ![](https://lh3.googleusercontent.com/proxy/SB_X181yQGIQtTUCw3Dz0xbEKubOyoeC8dQKKSKFjRvq6jllISiB52ZQxUKWyHVqQuehEFS7JOPZQ_qOBVVvp0me_pQs_u0mG5XcHbMSYEMvnNSJmNMh9v0)
#
# ## Installation
#
# There are three parts to the installation.
# - MongoDB Server
# - Mongo Compass
# - pymongo
#
# Follow these instructions depending on your Operating System

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Installation" data-toc-modified-id="Installation-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Installation</a></span></li><li><span><a href="#macOS" data-toc-modified-id="macOS-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>macOS</a></span><ul class="toc-item"><li><span><a href="#Server" data-toc-modified-id="Server-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Server</a></span><ul class="toc-item"><li><span><a href="#Dependencies" data-toc-modified-id="Dependencies-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Dependencies</a></span></li><li><span><a href="#Installation" data-toc-modified-id="Installation-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Installation</a></span></li><li><span><a href="#Starting-and-stoping-Server" data-toc-modified-id="Starting-and-stoping-Server-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Starting and stoping Server</a></span></li></ul></li><li><span><a href="#Mongo-Compass" data-toc-modified-id="Mongo-Compass-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Mongo Compass</a></span><ul class="toc-item"><li><span><a href="#Installation" data-toc-modified-id="Installation-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Installation</a></span></li></ul></li><li><span><a href="#pymongo" data-toc-modified-id="pymongo-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>pymongo</a></span></li><li><span><a href="#Documentation" data-toc-modified-id="Documentation-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Documentation</a></span></li></ul></li><li><span><a href="#Windows" data-toc-modified-id="Windows-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Windows</a></span><ul class="toc-item"><li><span><a href="#Server" data-toc-modified-id="Server-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Server</a></span><ul class="toc-item"><li><span><a href="#Installation" data-toc-modified-id="Installation-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Installation</a></span></li><li><span><a href="#Starting-and-stoping-Server" data-toc-modified-id="Starting-and-stoping-Server-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Starting and stoping Server</a></span></li></ul></li><li><span><a href="#Mongo-Compass" data-toc-modified-id="Mongo-Compass-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Mongo Compass</a></span><ul class="toc-item"><li><span><a href="#Installation" data-toc-modified-id="Installation-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Installation</a></span></li></ul></li><li><span><a href="#pymongo" data-toc-modified-id="pymongo-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>pymongo</a></span></li><li><span><a href="#Documentation" data-toc-modified-id="Documentation-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Documentation</a></span></li></ul></li><li><span><a href="#Ubuntu" data-toc-modified-id="Ubuntu-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Ubuntu</a></span><ul class="toc-item"><li><span><a href="#Server" data-toc-modified-id="Server-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Server</a></span><ul class="toc-item"><li><span><a href="#Dependencies" data-toc-modified-id="Dependencies-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Dependencies</a></span></li><li><span><a href="#Installation" data-toc-modified-id="Installation-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Installation</a></span></li><li><span><a href="#Starting-and-stoping-Server" data-toc-modified-id="Starting-and-stoping-Server-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Starting and stoping Server</a></span></li></ul></li><li><span><a href="#Mongo-Compass" data-toc-modified-id="Mongo-Compass-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Mongo Compass</a></span><ul class="toc-item"><li><span><a href="#Installation" data-toc-modified-id="Installation-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Installation</a></span></li></ul></li><li><span><a href="#pymongo" data-toc-modified-id="pymongo-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>pymongo</a></span></li><li><span><a href="#Documentation" data-toc-modified-id="Documentation-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Documentation</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## macOS
#
# ### Server
# #### Dependencies
#
# - You'll neeb homebrew, but you should already have it by now.
# - Make sure you have Xcode installed
# ```bash
# xcode-select --install
# ```
# You should see the following output if you already have it installed, otherwise, it will install:
#
# >```
# xcode-select: error: command line tools are already installed, use "Software Update" to install updates
# >```
#
# #### Installation
#
# Run the following two commands in order to install the server.
#
# ```bash
# brew tap mongodb/brew
# ```
#
# ```bash
# brew install mongodb-community
# ```
#
# #### Starting and stoping Server
#
# ```bash
# brew services start mongodb-community
# ```
#
# ```bash
# brew services stop mongodb-community
# ```
#
# ### Mongo Compass
# This is our GUI.
#
# #### Installation
# You will find the installer for download on this [link](https://www.mongodb.com/try/download/compass).
#
# Just download it for your OS, double click and follow the instructions on screen.
#
# ### pymongo
#
# ```bash
# pip install pymongo
# ```
#
# ### Documentation
# - [Install MongoDB Server on macOS](https://docs.mongodb.com/manual/tutorial/install-mongodb-on-os-x/)
# - [Install Mongo Compass](https://docs.mongodb.com/compass/master/install)
# - [Install pymongo](https://pymongo.readthedocs.io/en/stable/installation.html)

# %% [markdown]
# ![](https://www.livelifekingsize.net/wp-content/uploads/2017/10/separator-green.png)

# %% [markdown]
# ## Windows
#
# ### Server
#
# #### Installation
# Download `.msi` installer from this [link](https://www.mongodb.com/try/download/community?tck=docs_server).
#
# Execute the installer, follow the instructions on screen. Choose a complete instalation and to install it as a Windows Service when prompted.
#
# ![](https://docs.mongodb.com/manual/_images/windows-installer.png)
#
# Also:
#
# `Choose the option to install Mongo Compass.`
#
# This way we do two things at once and can skip the next installation.
#
# #### Starting and stoping Server
#
# Open the Services Console, just search for Services on the Start Button.
#
# Right-click on the MongoDB service and click Start or Stop.
#
#
# ### Mongo Compass
# This is our GUI.
#
# #### Installation
# If you have `not` installed it with the server, you should download and install Mongo Compass.
#
# You will find the installer for download on this [link](https://www.mongodb.com/try/download/compass).
#
# Just download it for your OS, double click and follow the instructions on screen.
#
# ### pymongo
#
# ```bash
# pip install pymongo
# ```
#
# ### Documentation
# - [Install MongoDB Server on Windows](https://docs.mongodb.com/manual/tutorial/install-mongodb-on-windows/#install-mongodb-community-edition)
# - [Install Mongo Compass](https://docs.mongodb.com/compass/master/install)
# - [Install pymongo](https://pymongo.readthedocs.io/en/stable/installation.html)

# %% [markdown]
# ![](https://www.livelifekingsize.net/wp-content/uploads/2017/10/separator-green.png)

# %% [markdown]
# ## Ubuntu
#
# ### Server
# #### Dependencies
#
# - You will need to add MongoDB to apt, execute the following command on the terminal.
#
# ```bash
# wget -qO - https://www.mongodb.org/static/pgp/server-4.4.asc | sudo apt-key add -
# ```
# It should return an OK.
#
# ---
# `IF` and only `IF` you have an error indicating gnupg is not installed, type the following commands:
#
# >```bash
# sudo apt-get install gnupg
# >```
# then
# >```bash
# wget -qO - https://www.mongodb.org/static/pgp/server-4.4.asc | sudo apt-key add -
# >```
# ---
# Finally (whether you had to install gnupg or `not`, either way), execute the following:
#
# ```bash
# echo "deb [ arch=amd64,arm64 ] https://repo.mongodb.org/apt/ubuntu focal/mongodb-org/4.4 multiverse" | sudo tee /etc/apt/sources.list.d/mongodb-org-4.4.list
# ```
#
# #### Installation
#
# Just execute this and wait.
#
# ```bash
# sudo apt-get install -y mongodb-org
# ```
#
# #### Starting and stoping Server
#
# ```bash
# sudo systemctl start mongod
# ```
#
# ```bash
# sudo systemctl stop mongod
# ```
#
# ### Mongo Compass
# This is our GUI.
#
# #### Installation
# You will find the installer for download on this [link](https://www.mongodb.com/try/download/compass).
#
# Just download it for your OS, double click and follow the instructions on screen.
#
# ### pymongo
#
# ```bash
# pip install pymongo
# ```
#
# ### Documentation
# - [Install MongoDB Server on Ubuntu](https://docs.mongodb.com/manual/tutorial/install-mongodb-on-ubuntu/#install-mongodb-community-edition)
# - [Install Mongo Compass](https://docs.mongodb.com/compass/master/install)
# - [Install pymongo](https://pymongo.readthedocs.io/en/stable/installation.html)
