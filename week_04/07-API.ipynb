# %%
from flask import Flask

# %%
app = Flask("Felipe's_API")

# %%
# app.run()

# %% [markdown]
# ## URL
#
# `http://127.0.0.1:5000/`
#
# ![](https://qph.fs.quoracdn.net/main-qimg-1df2405abe09c3bac85c7491686e3073)
#
# - SCHEME: `Protocol`
# - PATH: `endpoint`
# - QUERY STRING: `query params`

# %%
@app.route("/")
def root():
    return {"Hello":"World!"}

# %%
#app.run()

# %%
@app.route("/test")
def test():
    print("Someone requested /test")
    return {"response":None}

# %%
#app.run()

# %% [markdown]
# ## Params (URL Params)
# - Parameters that are written on the URL
# ```python
# @app.route("/endpoint/<param1>/<param2>")
# def function(param1,param2):
#     pass
# ```

# %%
@app.route("/salute/<name>")
def salute(name):
    return {"Welcome":name}
#app.run()

# %% [markdown]
# ## Query Params (?param1=pa1&param2=pa2)
# - Parameters that are passes as a `query string`
# - Using requests, we pass them as `params={param1:pa1,etc..}`
# ```python
# @app.route("/endpoint")
# def function():
#     query_params = flask.request.args # dictionary {param1_name:pa1_value, etc..}
#     pass
# ```

# %%
from flask import request
@app.route("/who")
def who():
    args = request.args
    print(args)
    return {"Welcome":args.get("name")}
#app.run()
# Out:
#  * Serving Flask app "Felipe's_API" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [05/Feb/2021 10:29:20] "GET /who?name=pepe HTTP/1.1" 200 -
# ImmutableMultiDict([('name', 'pepe')])
# 127.0.0.1 - - [05/Feb/2021 10:29:25] "GET /who?name=Lola HTTP/1.1" 200 -
# ImmutableMultiDict([('name', 'Lola')])
# 127.0.0.1 - - [05/Feb/2021 10:29:30] "GET /who?name=Karen HTTP/1.1" 200 -
# ImmutableMultiDict([('name', 'Karen')])
# 127.0.0.1 - - [05/Feb/2021 10:29:47] "GET /who?name=Karen&last_name=Smith HTTP/1.1" 200 -
# ImmutableMultiDict([('name', 'Karen'), ('last_name', 'Smith')])

# %% [markdown]
# -----

# %%
url = "http://127.0.0.1:5000"

# %%
import requests

# %%
requests.get(url).json()
# Out:
# {'Welcome': 'to datamad0121 API'}

# %%
q = {"founded_year":2000}
q2 = {"name":"Facebook"} 
requests.get(url+"/company", params=q2).json()
# Out:
# [{'_id': {'$oid': '52cdef7c4bab8bd675297d8e'},
#   'name': 'Facebook',
#   'offices': [{'description': 'Headquarters',
#     'address1': '1601 Willow Road',
#     'address2': '',
#     'zip_code': '94025',
#     'city': 'Menlo Park',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.41605,
#     'longitude': -122.151801},
#    {'description': 'Europe HQ',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'Dublin',
#     'state_code': None,
#     'country_code': 'IRL',
#     'latitude': 53.344104,
#     'longitude': -6.267494},
#    {'description': 'New York',
#     'address1': '340 Madison Ave',
#     'address2': '',
#     'zip_code': '10017',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.7557162,
#     'longitude': -73.9792469}]}]

# %%
url = "http://127.0.0.1:5000"
endpoint = "/params"
params = "/hello/jeancha"
full_path = url+endpoint+params
print(full_path)

requests.get(full_path).json()
# Out:
# http://127.0.0.1:5000/params/hello/jeancha
# {'param1': 'hello', 'param2': 'jeancha'}

# %%
url = "http://127.0.0.1:5000"
endpoint = "/query"
full_path = url+endpoint

query = {
    "a":7,
    "b":5,
    "c":8,
    "Sonia":"Hola!"
}
print(full_path)

response = requests.get(full_path, params=query)
# Out:
# http://127.0.0.1:5000/query

# %%
response.url
# Out:
# 'http://127.0.0.1:5000/query?a=7&b=5&c=8&Sonia=Hola%21'

# %%
response
# Out:
# <Response [200]>

# %%
result = response.json()
result
# Out:
# {'Sonia': 'Hola!', 'a': '7', 'b': '5', 'c': '8'}

# %%
type(result)
# Out:
# dict

# %%
result["a"]
# Out:
# '7'

# %%
url = "http://127.0.0.1:5000"
endpoint = "/whoami"
full_path = url+endpoint

query = {
    "name":"Pepe",
    "age": 32
}
print(full_path)

response = requests.get(full_path, params=query)
# Out:
# http://127.0.0.1:5000/whoami

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# 'Hola, soy Pepe, tengo 32 años'

# %%
url = "http://127.0.0.1:5000"
endpoint = "/company"
full_path = url+endpoint

query = {
    "founded_year":2000
}
print(full_path)

response = requests.get(full_path, params=query)
# Out:
# http://127.0.0.1:5000/company

# %%
response.json()
# Out:
# [{'_id': {'$oid': '52cdef7c4bab8bd675297dd5'},
#   'name': 'AllofMP3',
#   'offices': [{'description': None,
#     'address1': None,
#     'address2': None,
#     'zip_code': None,
#     'city': 'Moscow',
#     'state_code': None,
#     'country_code': 'RUS',
#     'latitude': 55.755786,
#     'longitude': 37.617633}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675297dd9'},
#   'name': 'Steorn',
#   'offices': [{'description': None,
#     'address1': 'East Wall Road',
#     'address2': 'Docklands Innovation Park',
#     'zip_code': '',
#     'city': 'Dublin',
#     'state_code': None,
#     'country_code': 'IRL',
#     'latitude': 53.354997,
#     'longitude': -6.229255}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675297ddb'},
#   'name': 'MeeVee',
#   'offices': [{'description': None,
#     'address1': '500 Airport Blvd., Suite 400',
#     'address2': None,
#     'zip_code': '94010',
#     'city': 'Burlingame',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.590339,
#     'longitude': -122.341715}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675297e38'},
#   'name': 'PhotoBox',
#   'offices': [{'description': 'PhotoBox HQ',
#     'address1': 'Bridge House',
#     'address2': '63-65 North Wharf Road',
#     'zip_code': 'W2 1LA',
#     'city': 'London',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675297e73'},
#   'name': 'Boonex',
#   'offices': [{'description': None,
#     'address1': '10 Cedar Grove',
#     'address2': 'Castle Hill',
#     'zip_code': '2154',
#     'city': 'Sydney',
#     'state_code': None,
#     'country_code': 'AUS',
#     'latitude': -33.722577,
#     'longitude': 150.981801}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675297ea9'},
#   'name': 'Sulake',
#   'offices': [{'description': 'World Headquarters',
#     'address1': 'Korkeavuorenkatu 35',
#     'address2': '',
#     'zip_code': '00130',
#     'city': 'Helsinki',
#     'state_code': None,
#     'country_code': 'FIN',
#     'latitude': 60.165166,
#     'longitude': 24.945937}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675297eb6'},
#   'name': 'SelectMinds',
#   'offices': [{'description': None,
#     'address1': '149 Fifth Avenue',
#     'address2': None,
#     'zip_code': '10010',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.740251,
#     'longitude': -73.990004}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675297ef2'},
#   'name': 'ContextWeb',
#   'offices': [{'description': None,
#     'address1': '22 Cortlandt Street',
#     'address2': '',
#     'zip_code': '10007',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.71014,
#     'longitude': -74.010808}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675297efd'},
#   'name': 'ZoomInfo',
#   'offices': [{'description': None,
#     'address1': '307 Waverley Oaks Road',
#     'address2': None,
#     'zip_code': '02452',
#     'city': 'Waltham',
#     'state_code': 'MA',
#     'country_code': 'USA',
#     'latitude': 42.38532,
#     'longitude': -71.207055}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675297f12'},
#   'name': 'eHarmony',
#   'offices': [{'description': '',
#     'address1': '2401 Colorado Avenue',
#     'address2': 'Suite A200',
#     'zip_code': '90404',
#     'city': 'Santa Monica',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 34.145946,
#     'longitude': -118.132351}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675297f39'},
#   'name': 'Espotting',
#   'offices': [{'description': None,
#     'address1': None,
#     'address2': None,
#     'zip_code': None,
#     'city': None,
#     'state_code': None,
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675297f3e'},
#   'name': 'airG',
#   'offices': [{'description': '',
#     'address1': 'Suite 710, 1133 Melville Street',
#     'address2': '',
#     'zip_code': 'V6E 4E5',
#     'city': 'Vancouver',
#     'state_code': None,
#     'country_code': 'CAN',
#     'latitude': 3.046111,
#     'longitude': -75.066111}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675297f63'},
#   'name': 'Marchex',
#   'offices': [{'description': 'Corporate Headquarters',
#     'address1': '520 Pike Street',
#     'address2': 'Suite 2000',
#     'zip_code': '98101',
#     'city': 'Seattle',
#     'state_code': 'WA',
#     'country_code': 'USA',
#     'latitude': 47.611201,
#     'longitude': -122.336825}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675297f7a'},
#   'name': 'ContactOffice',
#   'offices': [{'description': '',
#     'address1': 'Rue Middelbourg 64 B',
#     'address2': '',
#     'zip_code': '1170',
#     'city': 'Brussel',
#     'state_code': None,
#     'country_code': 'BEL',
#     'latitude': 50.796645,
#     'longitude': 4.400604}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675297f99'},
#   'name': 'WooMe',
#   'offices': [{'description': None,
#     'address1': '3832 Hemingway',
#     'address2': None,
#     'zip_code': '92606',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675297fd9'},
#   'name': 'Boomi',
#   'offices': [{'description': 'Headquarters',
#     'address1': '801 Cassatt Road',
#     'address2': 'Suite 120',
#     'zip_code': '19312',
#     'city': 'Berwyn',
#     'state_code': 'PA',
#     'country_code': 'USA',
#     'latitude': 40.063476,
#     'longitude': -75.457492},
#    {'description': 'West Coast',
#     'address1': '473 Jackson Street',
#     'address2': 'Third Floor',
#     'zip_code': '94111',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd67529802f'},
#   'name': 'zSlide',
#   'offices': [{'description': None,
#     'address1': '111 r Marceau',
#     'address2': None,
#     'zip_code': '93100',
#     'city': 'Montreuil',
#     'state_code': None,
#     'country_code': 'FRA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675298058'},
#   'name': 'Phrasebase',
#   'offices': [{'description': 'Headquarters',
#     'address1': '59/8 Moo 9 Soi Sukee',
#     'address2': 'Muang Tambon Chalong',
#     'zip_code': '83130',
#     'city': 'Phuket',
#     'state_code': None,
#     'country_code': 'THA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675298064'},
#   'name': 'Ubertor',
#   'offices': [{'description': '',
#     'address1': 'Suite #215 130-8191 Westminster Highway',
#     'address2': '',
#     'zip_code': 'V6X 1A7',
#     'city': 'Richmond',
#     'state_code': None,
#     'country_code': 'CAN',
#     'latitude': 49.25403,
#     'longitude': -123.115208}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd67529806a'},
#   'name': 'JobDig',
#   'offices': [{'description': '',
#     'address1': '10300 Valley View Rd',
#     'address2': 'Suite 101',
#     'zip_code': '55344',
#     'city': 'Eden Prairie',
#     'state_code': 'MN',
#     'country_code': 'USA',
#     'latitude': 44.871371,
#     'longitude': -93.407837}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd67529808b'},
#   'name': 'Quigo',
#   'offices': [{'description': None,
#     'address1': '90 Park Avenue, 10th Floor',
#     'address2': None,
#     'zip_code': '10016',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.907974,
#     'longitude': -73.84179}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd6752980af'},
#   'name': 'Compete',
#   'offices': [{'description': 'Compete',
#     'address1': '501 Boylston St',
#     'address2': 'Suite 6101',
#     'zip_code': '02116',
#     'city': 'Boston',
#     'state_code': 'MA',
#     'country_code': 'USA',
#     'latitude': 42.346743,
#     'longitude': -71.076632}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd6752980f8'},
#   'name': 'LinkStorm',
#   'offices': [{'description': 'HQ',
#     'address1': '34 West 22nd Street',
#     'address2': '',
#     'zip_code': '10010',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675298101'},
#   'name': 'iStockphoto',
#   'offices': [{'description': 'HQ',
#     'address1': '1202 - 20 Avenue SE',
#     'address2': '',
#     'zip_code': 'AB T2G 1M8',
#     'city': 'Calgary',
#     'state_code': None,
#     'country_code': 'CAN',
#     'latitude': 51.035669,
#     'longitude': -114.036678}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675298107'},
#   'name': 'beRecruited',
#   'offices': [{'description': 'beRecruited Headquarters',
#     'address1': '539 Bryant St',
#     'address2': '',
#     'zip_code': '94117',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 33.754487,
#     'longitude': -84.389663}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675298157'},
#   'name': 'FastBooking',
#   'offices': [{'description': 'FastBooking',
#     'address1': '63 avenue des Champs Elysées',
#     'address2': '',
#     'zip_code': '75008',
#     'city': 'Paris',
#     'state_code': None,
#     'country_code': 'FRA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675298163'},
#   'name': 'Smilebox',
#   'offices': [{'description': None,
#     'address1': '8201 164th Ave NE',
#     'address2': 'Suite 305',
#     'zip_code': '98052',
#     'city': 'Redmond',
#     'state_code': 'WA',
#     'country_code': 'USA',
#     'latitude': 47.676378,
#     'longitude': -122.122155}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675298180'},
#   'name': 'Deem',
#   'offices': [{'description': 'HQ',
#     'address1': '301 Howard Street',
#     'address2': '20th Floor',
#     'zip_code': '94105',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.559836,
#     'longitude': -122.271532},
#    {'description': 'Scottsdale, Arizona',
#     'address1': '15990 North Greenway Hayden Loop',
#     'address2': '',
#     'zip_code': '85260',
#     'city': 'Scotts',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Bangalore India Office',
#     'address1': 'Level 8, Prestige Obelisk No 3',
#     'address2': 'Kasturba Road Bangalore',
#     'zip_code': '560001',
#     'city': 'Bangalore',
#     'state_code': None,
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Secaucus, New Jersey',
#     'address1': '333 Meadowlands Pkwy.',
#     'address2': '1st Floor',
#     'zip_code': '07094',
#     'city': 'Secaucus',
#     'state_code': 'NJ',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675298181'},
#   'name': 'CDNetworks',
#   'offices': [{'description': '',
#     'address1': '441 W. Trimble Road',
#     'address2': '',
#     'zip_code': 'CA 95134',
#     'city': 'San Jose',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.4050988,
#     'longitude': -121.9477639}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd6752981a7'},
#   'name': 'TripAdvisor',
#   'offices': [{'description': '',
#     'address1': '141 Needham Street',
#     'address2': '',
#     'zip_code': '02464',
#     'city': 'Newton',
#     'state_code': 'MA',
#     'country_code': 'USA',
#     'latitude': 42.312908,
#     'longitude': -71.212341}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd6752981de'},
#   'name': 'Oversee',
#   'offices': [{'description': 'Headquarters',
#     'address1': '515 S. Flower Street Suite 4400',
#     'address2': '',
#     'zip_code': '90071',
#     'city': 'Los Angeles',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 34.051368,
#     'longitude': -118.256305}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675298239'},
#   'name': 'iModules Software',
#   'offices': [{'description': None,
#     'address1': '7400 W. 132nd Street, Suite 300',
#     'address2': '',
#     'zip_code': '66213',
#     'city': 'Overland Park',
#     'state_code': 'KS',
#     'country_code': 'USA',
#     'latitude': 38.89055,
#     'longitude': -94.671644}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd6752982bf'},
#   'name': 'eTeacher',
#   'offices': [{'description': None,
#     'address1': '8 Oholiav ST',
#     'address2': '',
#     'zip_code': '52522',
#     'city': 'Ramat Gan',
#     'state_code': None,
#     'country_code': 'ISR',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd6752982c5'},
#   'name': 'uVuMobile',
#   'offices': [{'description': None,
#     'address1': '2160 Satellite Blvd.',
#     'address2': 'Suite 130',
#     'zip_code': '30097',
#     'city': 'Duluth',
#     'state_code': 'GA',
#     'country_code': 'USA',
#     'latitude': 33.984004,
#     'longitude': -84.092596}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd6752982c9'},
#   'name': 'Escapia',
#   'offices': [{'description': None,
#     'address1': '2101 4th Ave',
#     'address2': 'STE 1800',
#     'zip_code': '98121',
#     'city': 'Seattle',
#     'state_code': 'WA',
#     'country_code': 'USA',
#     'latitude': 47.613896,
#     'longitude': -122.3413},
#    {'description': '',
#     'address1': '1011 W 5th Street #300',
#     'address2': '',
#     'zip_code': '78703',
#     'city': 'Austin',
#     'state_code': 'TX',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675298312'},
#   'name': 'Betfair',
#   'offices': [{'description': 'UK Headquarters',
#     'address1': 'South Wing, Waterfront Chancellors Road Hammersmith Embankment',
#     'address2': '',
#     'zip_code': 'W6 9HP',
#     'city': 'London',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': 52.4624161,
#     'longitude': 1.696829}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675298336'},
#   'name': 'Maktoob',
#   'offices': [{'description': 'HQ',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'Amman',
#     'state_code': None,
#     'country_code': 'JOR',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd67529833b'},
#   'name': 'Ownersite Technologies',
#   'offices': [{'description': 'Headquarters',
#     'address1': '885 Woodstock Road',
#     'address2': 'Suite 430-187',
#     'zip_code': '30075-2274',
#     'city': 'Roswell',
#     'state_code': 'GA',
#     'country_code': 'USA',
#     'latitude': 34.016362,
#     'longitude': -84.322687}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675298349'},
#   'name': 'SnapNames',
#   'offices': [{'description': '',
#     'address1': '1600 SW 4th Ave',
#     'address2': 'Suite 400',
#     'zip_code': '97201',
#     'city': 'Portland',
#     'state_code': 'OR',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675298352'},
#   'name': 'Online-Access',
#   'offices': [{'description': 'Main Office',
#     'address1': '2650 Oak Street',
#     'address2': '',
#     'zip_code': '48060',
#     'city': 'Port Huron',
#     'state_code': 'MI',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675298354'},
#   'name': 'Exalead',
#   'offices': [{'description': None,
#     'address1': '10 place de la madeleine',
#     'address2': '',
#     'zip_code': '75008',
#     'city': 'Paris',
#     'state_code': None,
#     'country_code': 'FRA',
#     'latitude': 48.86931,
#     'longitude': 2.324782}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675298366'},
#   'name': 'Hotwire',
#   'offices': [{'description': '',
#     'address1': '655 Montgomery Street',
#     'address2': 'Ste. 600',
#     'zip_code': '94111',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.795236,
#     'longitude': -122.403607}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd67529837b'},
#   'name': 'StubHub',
#   'offices': [{'description': '',
#     'address1': '199 Fremont St',
#     'address2': 'Fl 4',
#     'zip_code': '94105',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.7892685,
#     'longitude': -122.3951844}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675298381'},
#   'name': 'Project10X',
#   'offices': [{'description': 'Project10X',
#     'address1': '2853 Ontario Road #501',
#     'address2': '',
#     'zip_code': '20009',
#     'city': 'Washington',
#     'state_code': 'DC',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd67529839f'},
#   'name': 'Ephox',
#   'offices': [{'description': 'HQ',
#     'address1': '1625 North Market Boulevard,',
#     'address2': 'Suite S202',
#     'zip_code': '95834',
#     'city': 'Sacramento',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.444188,
#     'longitude': -122.163745},
#    {'description': 'Aussie Office',
#     'address1': '261 Given Tce',
#     'address2': '',
#     'zip_code': '4064',
#     'city': 'Paddington',
#     'state_code': None,
#     'country_code': 'AUS',
#     'latitude': -27.460736,
#     'longitude': 153.004254},
#    {'description': 'UK Office',
#     'address1': 'Suite 4',
#     'address2': '110 High Street',
#     'zip_code': 'SL6 1PT',
#     'city': 'Maidenhead',
#     'state_code': 'CA',
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd6752983e8'},
#   'name': 'Fibre2fashion',
#   'offices': [{'description': None,
#     'address1': 'Sanblue Enterprises Pvt. Ltd',
#     'address2': '201-203, Sapphire tower, Nr. Cargo motors,',
#     'zip_code': '',
#     'city': 'Ahmedabad',
#     'state_code': None,
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd6752984cc'},
#   'name': 'LiveOps',
#   'offices': [{'description': 'HQ',
#     'address1': '5425 Stevens Creek Blvd.',
#     'address2': '',
#     'zip_code': '95051',
#     'city': 'Santa Clara',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.323668,
#     'longitude': -122.004204}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd6752984d6'},
#   'name': 'PointRoll',
#   'offices': [{'description': 'Headquarters',
#     'address1': '3200 Horizon Drive Suite 120',
#     'address2': '',
#     'zip_code': '19406',
#     'city': 'King of Prussia',
#     'state_code': 'PA',
#     'country_code': 'USA',
#     'latitude': 40.0750511,
#     'longitude': -75.2904912}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675298515'},
#   'name': 'Jelsoft',
#   'offices': [{'description': 'UK Office',
#     'address1': 'Howarth Lodge',
#     'address2': '7 Reading Road, Pangbourne',
#     'zip_code': 'RG8 7LR',
#     'city': 'Berkshire',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd67529853a'},
#   'name': 'Cenzic',
#   'offices': [{'description': 'Corporate Headquarters',
#     'address1': '655 Campbell Technology Parkway',
#     'address2': 'Suite 100',
#     'zip_code': '95008',
#     'city': 'Campbell',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.2816136,
#     'longitude': -121.9410679}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675298581'},
#   'name': 'Ecommerce Solutions',
#   'offices': [{'description': None,
#     'address1': '12 Windemere Ct',
#     'address2': '',
#     'zip_code': '07981',
#     'city': 'Whippany',
#     'state_code': 'NJ',
#     'country_code': 'USA',
#     'latitude': 40.83812,
#     'longitude': -74.429479}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd67529858a'},
#   'name': 'Akampus',
#   'offices': [{'description': '',
#     'address1': 'Ebulula Cad. Ülgen Sok. 18A/1 No:132',
#     'address2': 'Levent',
#     'zip_code': '34330',
#     'city': 'Istanbul',
#     'state_code': None,
#     'country_code': 'TUR',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd6752985bf'},
#   'name': 'Glaxstar',
#   'offices': [{'description': None,
#     'address1': 'One Victoria Square',
#     'address2': '',
#     'zip_code': '',
#     'city': 'Birmingham',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': 52.479554,
#     'longitude': -1.903186}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd6752985db'},
#   'name': 'Greater Than One',
#   'offices': [{'description': 'HQ',
#     'address1': '395 Hudson Street',
#     'address2': '4th Floor',
#     'zip_code': '10014',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd6752985ff'},
#   'name': 'Wellwrittenwords',
#   'offices': [{'description': None,
#     'address1': '',
#     'address2': '',
#     'zip_code': '27606',
#     'city': '',
#     'state_code': 'NC',
#     'country_code': 'USA',
#     'latitude': 35.737593,
#     'longitude': -78.721192}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd67529862e'},
#   'name': 'Parature',
#   'offices': [{'description': '',
#     'address1': '13625 –B Dulles Technology Drive',
#     'address2': '',
#     'zip_code': '20171',
#     'city': 'Herndon',
#     'state_code': 'VA',
#     'country_code': 'USA',
#     'latitude': 38.912791,
#     'longitude': -77.220048}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675298649'},
#   'name': 'Higher One',
#   'offices': [{'description': 'HQ',
#     'address1': '25 Science Park',
#     'address2': '',
#     'zip_code': '06511',
#     'city': 'New Haven',
#     'state_code': 'CT',
#     'country_code': 'USA',
#     'latitude': 41.3239577,
#     'longitude': -72.9268094}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd67529872c'},
#   'name': 'Zong',
#   'offices': [{'description': 'Headquarters',
#     'address1': '640 Oak Grove Avenue',
#     'address2': '',
#     'zip_code': '94025',
#     'city': 'Menlo Park',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.4429885,
#     'longitude': -122.1624131},
#    {'description': 'EU head office',
#     'address1': '43 rte des Acacias',
#     'address2': '',
#     'zip_code': '1227',
#     'city': 'Geneva',
#     'state_code': None,
#     'country_code': 'CHE',
#     'latitude': 46.1893709,
#     'longitude': 6.1311735},
#    {'description': 'German office',
#     'address1': 'Flinger Strasse 36',
#     'address2': '',
#     'zip_code': '40213',
#     'city': 'DÃ¼sseldorf',
#     'state_code': None,
#     'country_code': 'DEU',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd67529874a'},
#   'name': 'Axosoft',
#   'offices': [{'description': '',
#     'address1': '13835 N. Northsight Blvd',
#     'address2': 'Suite 205',
#     'zip_code': '85260',
#     'city': 'Scottsdale',
#     'state_code': 'AZ',
#     'country_code': 'USA',
#     'latitude': 33.55617,
#     'longitude': -111.884104}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675298783'},
#   'name': 'Fourth Media Technologies',
#   'offices': [{'description': None,
#     'address1': '',
#     'address2': '',
#     'zip_code': '380054',
#     'city': '',
#     'state_code': None,
#     'country_code': 'IND',
#     'latitude': 35.06108,
#     'longitude': -101.256663}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd6752987ae'},
#   'name': 'LocalWineEvents',
#   'offices': [{'description': None,
#     'address1': '2042 General Alexander Drive',
#     'address2': '',
#     'zip_code': '19355',
#     'city': 'Malvern',
#     'state_code': 'PA',
#     'country_code': 'USA',
#     'latitude': 40.084161,
#     'longitude': -75.471505}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd6752987ca'},
#   'name': 'Seattle Software',
#   'offices': [{'description': None,
#     'address1': '711 Sixth Avenue North, #200',
#     'address2': '',
#     'zip_code': '98109',
#     'city': 'Seattle',
#     'state_code': 'WA',
#     'country_code': 'USA',
#     'latitude': 47.625511,
#     'longitude': -122.344966}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd6752987d0'},
#   'name': 'Fubra',
#   'offices': [{'description': None,
#     'address1': 'Manor Coach House',
#     'address2': 'Church Hill',
#     'zip_code': 'GU12 4RQ',
#     'city': 'Aldershot',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd6752987fb'},
#   'name': 'eVIPlist',
#   'offices': [{'description': None,
#     'address1': '4401-A Connecticut Ave.  NW',
#     'address2': 'Suite 349',
#     'zip_code': '20008',
#     'city': 'Washington',
#     'state_code': 'DC',
#     'country_code': 'USA',
#     'latitude': 38.945762,
#     'longitude': -77.063922}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675298821'},
#   'name': 'Visible World',
#   'offices': [{'description': 'Headquarters',
#     'address1': '460 W. 34th St. Floor 14',
#     'address2': '',
#     'zip_code': '10001',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.75406,
#     'longitude': -73.999003}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd67529882e'},
#   'name': 'ReefEdge',
#   'offices': [{'description': 'HQ',
#     'address1': '2 Executive Drive',
#     'address2': '',
#     'zip_code': '07024',
#     'city': 'Fort Lee',
#     'state_code': 'NJ',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675298842'},
#   'name': 'General Wireless',
#   'offices': [{'description': 'HQ',
#     'address1': 'Ã…rstaÃ¤ngsvÃ¤gen 1 a',
#     'address2': '',
#     'zip_code': '101 32',
#     'city': 'Stockholm',
#     'state_code': None,
#     'country_code': 'SWE',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7c4bab8bd675298862'},
#   'name': 'Rate Beer',
#   'offices': [{'description': None,
#     'address1': '1421 Wood Rd',
#     'address2': '',
#     'zip_code': '95439',
#     'city': 'Fulton',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 38.483311,
#     'longitude': -122.775864}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298894'},
#   'name': 'Fog Creek Software',
#   'offices': [{'description': '',
#     'address1': '55 Broadway',
#     'address2': 'Floor 25',
#     'zip_code': '10006',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.706728,
#     'longitude': -74.012533}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd6752988aa'},
#   'name': 'Scanbuy',
#   'offices': [{'description': '',
#     'address1': '10 East 39th Street',
#     'address2': '10th Floor',
#     'zip_code': '10016',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.7512062,
#     'longitude': -73.9815333}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd6752988b3'},
#   'name': 'Modera',
#   'offices': [{'description': '',
#     'address1': 'Mõisa 4',
#     'address2': '',
#     'zip_code': '13522',
#     'city': 'Tallinn',
#     'state_code': None,
#     'country_code': 'EST',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd6752988b7'},
#   'name': 'Rising Sun Research',
#   'offices': [{'description': None,
#     'address1': '180 Pulteney Street',
#     'address2': '',
#     'zip_code': '5000',
#     'city': 'Adelaide',
#     'state_code': None,
#     'country_code': 'AUS',
#     'latitude': -34.926024,
#     'longitude': 138.606419}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd6752988e4'},
#   'name': 'PIER Systems',
#   'offices': [{'description': 'Headquarters',
#     'address1': '1204 Railroad Ave.',
#     'address2': 'Suite 200',
#     'zip_code': '98225',
#     'city': 'Bellingham',
#     'state_code': 'WA',
#     'country_code': 'USA',
#     'latitude': 48.7491018,
#     'longitude': -122.4779176}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298933'},
#   'name': 'Infinera Corporation',
#   'offices': [{'description': 'Headquarters',
#     'address1': '169 Java Drive',
#     'address2': '',
#     'zip_code': '94089',
#     'city': 'Sunnyvale',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.411877,
#     'longitude': -122.018277}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298940'},
#   'name': 'The Icon Factory',
#   'offices': [{'description': None,
#     'address1': '7204 West Friendly Ave.',
#     'address2': 'Building Two, Unit F',
#     'zip_code': '27410',
#     'city': 'Greensboro',
#     'state_code': 'NC',
#     'country_code': 'USA',
#     'latitude': 36.08901,
#     'longitude': -79.924117}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd67529895b'},
#   'name': 'SilverStripe',
#   'offices': [{'description': 'World Headquarters',
#     'address1': 'Level 4 & 5',
#     'address2': '97-99 Courtenay Place',
#     'zip_code': '6011',
#     'city': 'Wellington',
#     'state_code': None,
#     'country_code': 'NZL',
#     'latitude': 50.3835264,
#     'longitude': -3.6027256}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd67529895f'},
#   'name': 'AVIS eSolutions',
#   'offices': [{'description': '',
#     'address1': 'D-35,Sec-2',
#     'address2': '',
#     'zip_code': '201301',
#     'city': 'Noida',
#     'state_code': None,
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298976'},
#   'name': 'FusionOps',
#   'offices': [{'description': 'HQ',
#     'address1': '265 Santa Ana Court',
#     'address2': '',
#     'zip_code': '94085',
#     'city': 'Sunnyvale',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.3795251,
#     'longitude': -122.0106131}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd6752989b5'},
#   'name': 'YourTechOnline',
#   'offices': [{'description': None,
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'British Columbia',
#     'state_code': None,
#     'country_code': 'CAN',
#     'latitude': 54.112504,
#     'longitude': -126.557612}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298a22'},
#   'name': 'Andera',
#   'offices': [{'description': 'HQ',
#     'address1': '15 Park Row West',
#     'address2': '2nd Floor',
#     'zip_code': '02903',
#     'city': 'Providence',
#     'state_code': 'RI',
#     'country_code': 'USA',
#     'latitude': 41.8283364,
#     'longitude': -71.4133543}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298a41'},
#   'name': 'Swamp Fox',
#   'offices': [{'description': None,
#     'address1': 'P. O. Box 27162',
#     'address2': '',
#     'zip_code': '29616-2162',
#     'city': 'Greenville',
#     'state_code': 'SC',
#     'country_code': 'USA',
#     'latitude': 34.8525,
#     'longitude': -82.3944}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298a98'},
#   'name': 'Sawfish Software',
#   'offices': [{'description': None,
#     'address1': 'Kings House',
#     'address2': '12 King Street',
#     'zip_code': 'YO1 9WP',
#     'city': 'York',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298acc'},
#   'name': 'deviantART',
#   'offices': [{'description': None,
#     'address1': '7095 Hollywood Blvd #788',
#     'address2': '',
#     'zip_code': '90028',
#     'city': 'Hollywood',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 34.101578,
#     'longitude': -118.33334}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298b0e'},
#   'name': 'Geary Interactive',
#   'offices': [{'description': 'Headquarters',
#     'address1': '720 Market Street',
#     'address2': 'Suite 600',
#     'zip_code': '94102',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.7872512,
#     'longitude': -122.4039768},
#    {'description': 'San Diego Office',
#     'address1': '401 West A Street',
#     'address2': 'Suite 360',
#     'zip_code': '92101',
#     'city': 'San Diego',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 32.718379,
#     'longitude': -117.160661}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298b10'},
#   'name': 'ITSportsNet',
#   'offices': [{'description': None,
#     'address1': '214 - 11th Ave SE',
#     'address2': 'Suite 210',
#     'zip_code': 'T2G 0X8',
#     'city': 'Calgary',
#     'state_code': None,
#     'country_code': 'CAN',
#     'latitude': 51.042296,
#     'longitude': -114.06044}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298b33'},
#   'name': 'MediaRush',
#   'offices': [{'description': None,
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': '',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': 55.378051,
#     'longitude': -3.435973}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298b8d'},
#   'name': 'CompareNetworks',
#   'offices': [{'description': None,
#     'address1': '395 Oyster Point Blvd',
#     'address2': 'Ste 330',
#     'zip_code': '94080',
#     'city': 'South San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.667304,
#     'longitude': -122.382792}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298b97'},
#   'name': 'sph3re',
#   'offices': [{'description': None,
#     'address1': '11 rue Philippe Jourde',
#     'address2': '',
#     'zip_code': '13500',
#     'city': 'Martigues',
#     'state_code': None,
#     'country_code': 'FRA',
#     'latitude': 43.400422,
#     'longitude': 5.055732}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298b9d'},
#   'name': 'Stockhouse',
#   'offices': [{'description': None,
#     'address1': '500, 750 West Pender Street',
#     'address2': '',
#     'zip_code': 'V6C 2T7',
#     'city': 'Vancouver',
#     'state_code': None,
#     'country_code': 'CAN',
#     'latitude': 49.284971,
#     'longitude': -123.115356}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298c09'},
#   'name': 'Vaultus Mobile',
#   'offices': [{'description': 'Corporate Headquarters',
#     'address1': '263 Summer Street',
#     'address2': '',
#     'zip_code': '02210',
#     'city': 'Boston',
#     'state_code': 'MA',
#     'country_code': 'USA',
#     'latitude': 42.350359,
#     'longitude': -71.0506234}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298c0a'},
#   'name': 'Handmark',
#   'offices': [{'description': 'World Headquarters',
#     'address1': '909 Walnut Street #400',
#     'address2': '',
#     'zip_code': '64106',
#     'city': 'Kansas City',
#     'state_code': 'MO',
#     'country_code': 'USA',
#     'latitude': 39.103151,
#     'longitude': -94.581908},
#    {'description': 'Texas Office',
#     'address1': '285 E Grand Ave #220',
#     'address2': '',
#     'zip_code': '76092',
#     'city': 'Southlake',
#     'state_code': 'TX',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298c1c'},
#   'name': 'Invensis Technologies',
#   'offices': [{'description': 'Headquarters',
#     'address1': '34/1 Upkar Chambers',
#     'address2': 'R V Road',
#     'zip_code': '560004',
#     'city': 'Bangalore',
#     'state_code': None,
#     'country_code': 'IND',
#     'latitude': 12.97128,
#     'longitude': 77.52677},
#    {'description': 'US Office',
#     'address1': '1000 N West Street',
#     'address2': 'Suite 1200',
#     'zip_code': '19801',
#     'city': 'Wilmington',
#     'state_code': 'DE',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298c20'},
#   'name': 'RMW Web Publishing',
#   'offices': [{'description': None,
#     'address1': '',
#     'address2': '',
#     'zip_code': '2795',
#     'city': 'Bathurst',
#     'state_code': None,
#     'country_code': 'AUS',
#     'latitude': -33.41978,
#     'longitude': 149.574258}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298c3b'},
#   'name': 'Versaly Entertainment',
#   'offices': [{'description': 'Main Office',
#     'address1': '',
#     'address2': '',
#     'zip_code': '98004',
#     'city': 'Bellevue',
#     'state_code': 'WA',
#     'country_code': 'USA',
#     'latitude': 47.626479,
#     'longitude': -122.205149}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298c90'},
#   'name': 'No Star Clothing',
#   'offices': [{'description': None,
#     'address1': '3580 NE Broadway',
#     'address2': '',
#     'zip_code': '97232',
#     'city': 'Portland',
#     'state_code': 'OR',
#     'country_code': 'USA',
#     'latitude': 45.53467,
#     'longitude': -122.626386}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298c92'},
#   'name': 'Navic Networks',
#   'offices': [{'description': None,
#     'address1': '201 Jones Road',
#     'address2': '',
#     'zip_code': '02451',
#     'city': 'Waltham',
#     'state_code': 'MA',
#     'country_code': 'USA',
#     'latitude': 42.375518,
#     'longitude': -71.272292}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298cad'},
#   'name': 'Internet Mall',
#   'offices': [{'description': 'Headquarters',
#     'address1': 'Delnicka 12',
#     'address2': '',
#     'zip_code': '17000',
#     'city': 'Praha',
#     'state_code': None,
#     'country_code': 'CZE',
#     'latitude': 49.817492,
#     'longitude': 15.472962}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298cb5'},
#   'name': 'Avaya',
#   'offices': [{'description': 'California',
#     'address1': '4655 Great America Parkway',
#     'address2': '',
#     'zip_code': '95054',
#     'city': 'Santa Clara',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.398076,
#     'longitude': -121.977333},
#    {'description': 'HQ',
#     'address1': '211 Mt Airy Road',
#     'address2': '',
#     'zip_code': '07920',
#     'city': 'Basking Ridge',
#     'state_code': 'NJ',
#     'country_code': 'USA',
#     'latitude': 40.694956,
#     'longitude': -74.577599}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298cf9'},
#   'name': 'ClickandBuy',
#   'offices': [{'description': None,
#     'address1': 'Im Mediapark 5',
#     'address2': '',
#     'zip_code': '50670',
#     'city': 'Cologne',
#     'state_code': None,
#     'country_code': 'DEU',
#     'latitude': 50.947699,
#     'longitude': 6.94205},
#    {'description': 'European headquarters',
#     'address1': 'Lincoln House',
#     'address2': '137-143 Hammersmith Road',
#     'zip_code': 'W14 0QL',
#     'city': 'London',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298d6a'},
#   'name': 'zanox',
#   'offices': [{'description': None,
#     'address1': 'Stralauer Allee 2',
#     'address2': '',
#     'zip_code': '10245',
#     'city': 'Berlin',
#     'state_code': None,
#     'country_code': 'DEU',
#     'latitude': 52.502642,
#     'longitude': 13.446834}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298d95'},
#   'name': 'Universal Clients',
#   'offices': []},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298d9d'},
#   'name': 'Bestofmedia Group',
#   'offices': [{'description': 'Global Headquarters',
#     'address1': '26 avenue de Gaulle',
#     'address2': '',
#     'zip_code': '92150',
#     'city': 'Suresnes',
#     'state_code': None,
#     'country_code': 'FRA',
#     'latitude': 48.8704095,
#     'longitude': 2.2246339},
#    {'description': 'U.S. Headquarters',
#     'address1': '9696 Culver Blvd',
#     'address2': '#104',
#     'zip_code': '90232',
#     'city': 'Culver City',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 34.0221299,
#     'longitude': -118.395743}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298dd8'},
#   'name': 'AnotherFriend',
#   'offices': []},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298dde'},
#   'name': 'Gratis Internet',
#   'offices': [{'description': '',
#     'address1': '1825 Eye Street NW, Suite 401',
#     'address2': '',
#     'zip_code': '20006',
#     'city': 'Washington',
#     'state_code': 'DC',
#     'country_code': 'USA',
#     'latitude': 38.901294,
#     'longitude': -77.032034}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298e20'},
#   'name': 'Astaro',
#   'offices': [{'description': 'Astaro GmbH & Co.KG',
#     'address1': 'Amalienbadstr. 41/Bau 52',
#     'address2': '',
#     'zip_code': '76227',
#     'city': 'Karlsruhe',
#     'state_code': None,
#     'country_code': 'DEU',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298e6a'},
#   'name': 'ViewNow',
#   'offices': [{'description': 'HQ',
#     'address1': '16255 Ventura Boulevard',
#     'address2': 'Suite 420',
#     'zip_code': '91436',
#     'city': 'Encino',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298e71'},
#   'name': 'LogicalApps',
#   'offices': [{'description': 'HQ',
#     'address1': '15420 Laguna Canyon Road',
#     'address2': 'Suite 150',
#     'zip_code': '92618',
#     'city': 'Irvine',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298ea0'},
#   'name': 'CPXi',
#   'offices': [{'description': 'Headquarters (NYC)',
#     'address1': '1441 Broadway',
#     'address2': '18th Floor',
#     'zip_code': '10018',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.7550708,
#     'longitude': -73.9869523},
#    {'description': 'Chicago Office',
#     'address1': 'One East Wacker Drive',
#     'address2': 'Suite 1850',
#     'zip_code': '60601',
#     'city': 'Chicago',
#     'state_code': 'IL',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298ecb'},
#   'name': 'Vodaco Web Strategies',
#   'offices': [{'description': 'Main Office',
#     'address1': 'Plaza 33, Buyukdere Cad. 33/11',
#     'address2': 'Sisli',
#     'zip_code': '34381',
#     'city': 'Istanbul',
#     'state_code': None,
#     'country_code': 'TUR',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298f61'},
#   'name': 'Gammoth',
#   'offices': [{'description': 'World Headquarters',
#     'address1': '717 Post Road',
#     'address2': '',
#     'zip_code': '53713',
#     'city': 'Madison',
#     'state_code': 'WI',
#     'country_code': 'USA',
#     'latitude': 43.027277,
#     'longitude': -89.392284}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298f63'},
#   'name': 'Freeportway',
#   'offices': [{'description': 'Home Office',
#     'address1': '66 Freeport St.',
#     'address2': '',
#     'zip_code': '02122',
#     'city': 'Boston',
#     'state_code': 'MA',
#     'country_code': 'USA',
#     'latitude': 42.305997,
#     'longitude': -71.057598},
#    {'description': 'R&D / Sales',
#     'address1': '25 School St.',
#     'address2': '',
#     'zip_code': '02169',
#     'city': 'Quincy',
#     'state_code': 'MA',
#     'country_code': 'USA',
#     'latitude': 42.244813,
#     'longitude': -71.001507}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298fa8'},
#   'name': 'JLOOP Rich Media',
#   'offices': [{'description': '',
#     'address1': '431 E. Broadway',
#     'address2': '',
#     'zip_code': '90802',
#     'city': 'Long Beach',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 33.769519,
#     'longitude': -118.186907}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298fb4'},
#   'name': 'MobiComp',
#   'offices': [{'description': '',
#     'address1': 'Rua do Parque Poente',
#     'address2': 'Lote 37 NÂº39',
#     'zip_code': '4705-629',
#     'city': 'Braga',
#     'state_code': None,
#     'country_code': 'PRT',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298fbb'},
#   'name': 'Clupedia',
#   'offices': [{'description': 'Corporate Headquarters',
#     'address1': '1300 S. Bristol Street',
#     'address2': '',
#     'zip_code': '92704-3424',
#     'city': 'Santa Ana',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 33.73076,
#     'longitude': -117.885161}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675298fe4'},
#   'name': 'thePlatform',
#   'offices': [{'description': 'Corporate Headquarters',
#     'address1': '1000 2nd Avenue',
#     'address2': 'Suite 1000',
#     'zip_code': '98104',
#     'city': 'Seattle',
#     'state_code': 'WA',
#     'country_code': 'USA',
#     'latitude': 47.617838,
#     'longitude': -122.356027}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd67529902e'},
#   'name': 'LifePics',
#   'offices': [{'description': 'LifePics HQ',
#     'address1': '5777 Central Ave. Ste. 120',
#     'address2': '',
#     'zip_code': '80304',
#     'city': 'Boulder',
#     'state_code': 'CO',
#     'country_code': 'USA',
#     'latitude': 40.025479,
#     'longitude': -105.219298}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675299039'},
#   'name': 'Mediastay',
#   'offices': [{'description': 'MEDIASTAY SAS',
#     'address1': '45 rue Jean Jaures',
#     'address2': '',
#     'zip_code': '92300',
#     'city': 'Levallois Perret',
#     'state_code': None,
#     'country_code': 'FRA',
#     'latitude': 48.891494,
#     'longitude': 2.292728},
#    {'description': 'MEDIASTAY NORTH AMERICA',
#     'address1': '350 Sansome Street',
#     'address2': '',
#     'zip_code': '94104',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd6752990f7'},
#   'name': 'Dot Com Infoway France',
#   'offices': [{'description': 'Corporate Headquarters',
#     'address1': '"GNG House"',
#     'address2': 'K-48, Anna Nagar East',
#     'zip_code': '600 102',
#     'city': 'Chennai',
#     'state_code': None,
#     'country_code': 'IND',
#     'latitude': 13.11352,
#     'longitude': 80.152135}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675299102'},
#   'name': 'KnowNow',
#   'offices': []},
#  {'_id': {'$oid': '52cdef7d4bab8bd67529913f'},
#   'name': 'Synology',
#   'offices': [{'description': 'Headquarters',
#     'address1': '6F-2, No. 106, Chang-An W. Rd.',
#     'address2': '',
#     'zip_code': '103',
#     'city': 'Taipei',
#     'state_code': None,
#     'country_code': 'TWN',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Synology America Corp.',
#     'address1': '2701 152nd Ave NE,',
#     'address2': '',
#     'zip_code': '98052',
#     'city': 'Redmond',
#     'state_code': 'WA',
#     'country_code': 'USA',
#     'latitude': 47.634824,
#     'longitude': -122.13771}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd67529915b'},
#   'name': 'Unisfair',
#   'offices': [{'description': 'Corporate Headquarters',
#     'address1': '149 Commonwealth Drive',
#     'address2': '',
#     'zip_code': '94025',
#     'city': 'Menlo Park',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.480999,
#     'longitude': -122.173887},
#    {'description': 'Israel Office',
#     'address1': '27 Habarzel Street',
#     'address2': '',
#     'zip_code': '69710',
#     'city': 'Tel Aviv',
#     'state_code': None,
#     'country_code': 'ISR',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'New York Office',
#     'address1': '1250 Broadway',
#     'address2': '31st floor',
#     'zip_code': '10001',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.7482,
#     'longitude': -73.988154}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675299163'},
#   'name': 'StoneFly',
#   'offices': [{'description': 'Corporate Headquarters',
#     'address1': '21353 Cabot Blvd.',
#     'address2': '',
#     'zip_code': '94545',
#     'city': 'Hayward',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.642185,
#     'longitude': -122.136819},
#    {'description': 'Development Headquarters',
#     'address1': '6191 Cornerstone Ct. East',
#     'address2': 'Suite 105',
#     'zip_code': '92121',
#     'city': 'San Diego',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 32.894501,
#     'longitude': -117.188304}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd6752991f1'},
#   'name': 'MixMeister',
#   'offices': [{'description': 'Corporate Headquarters',
#     'address1': '9805 NE 116th Street',
#     'address2': '# 7343',
#     'zip_code': '98034',
#     'city': 'Kirkland',
#     'state_code': 'WA',
#     'country_code': 'USA',
#     'latitude': 47.704028,
#     'longitude': -122.210339}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd6752991fc'},
#   'name': 'Zoomix',
#   'offices': [{'description': '',
#     'address1': 'Building 3, Chiswick Park',
#     'address2': '566 Chiswick High Road',
#     'zip_code': 'W4 5YA',
#     'city': 'London',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': 51.462904,
#     'longitude': -0.263377}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd6752991ff'},
#   'name': 'Caspio',
#   'offices': [{'description': 'Headquarters',
#     'address1': '485 N. Whisman Rd.',
#     'address2': 'Suite 200',
#     'zip_code': '94043',
#     'city': 'Mountain View',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.401165,
#     'longitude': -122.058128}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675299209'},
#   'name': 'Gigablast',
#   'offices': [{'description': '',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'Albuquerque',
#     'state_code': 'NM',
#     'country_code': 'USA',
#     'latitude': 35.08133,
#     'longitude': -106.626718}]},
#  {'_id': {'$oid': '52cdef7d4bab8bd675299234'},
#   'name': 'Dexterra',
#   'offices': [{'description': 'Corporate Headquarters',
#     'address1': '21540 30th Dr SE',
#     'address2': 'Suite 230',
#     'zip_code': '98021',
#     'city': 'Bothell',
#     'state_code': 'WA',
#     'country_code': 'USA',
#     'latitude': 47.802184,
#     'longitude': -122.196307},
#    {'description': 'Dexterra Canada',
#     'address1': '55 York St',
#     'address2': 'Suite 800',
#     'zip_code': 'M5J 1R7',
#     'city': 'Toronto, Ontario',
#     'state_code': None,
#     'country_code': 'CAN',
#     'latitude': 43.645702,
#     'longitude': -79.382594},
#    {'description': 'Dexterra Germany',
#     'address1': 'Marktstrasse 8',
#     'address2': '',
#     'zip_code': 'D-50968',
#     'city': 'Cologne',
#     'state_code': None,
#     'country_code': 'DEU',
#     'latitude': 50.911182,
#     'longitude': 6.96106},
#    {'description': 'Dexterra Middle East',
#     'address1': 'Suite 604',
#     'address2': 'Dubai Silicon Oasis',
#     'zip_code': '',
#     'city': 'Dubai',
#     'state_code': None,
#     'country_code': 'ARE',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Dexterra Americas',
#     'address1': '1600 Seaport Blvd',
#     'address2': 'Suite 200 North Bldg',
#     'zip_code': '94063',
#     'city': 'Redwood City',
#     'state_code': 'CA',
# ...
#     'state_code': 'PA',
#     'country_code': 'USA',
#     'latitude': 39.9587169,
#     'longitude': -75.1583802}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c2a2'},
#   'name': 'AbCRO',
#   'offices': [{'description': '',
#     'address1': '929 North Front Street',
#     'address2': '',
#     'zip_code': 'NC 28401-3331',
#     'city': 'Wilmington,',
#     'state_code': None,
#     'country_code': 'USA',
#     'latitude': 34.2458329,
#     'longitude': -77.9486992}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c2b8'},
#   'name': 'Fisher Vista',
#   'offices': [{'description': '',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'Capitola',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 36.978687,
#     'longitude': -121.953123}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c2cd'},
#   'name': 'XDx',
#   'offices': [{'description': '',
#     'address1': '3260 Bayshore Blvd.',
#     'address2': '',
#     'zip_code': '94005',
#     'city': 'Brisbane',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.691226,
#     'longitude': -122.4040269}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c300'},
#   'name': 'Woodland Biofuels',
#   'offices': [{'description': 'Head Office',
#     'address1': '220 Superior Boulevard',
#     'address2': 'Mississauga',
#     'zip_code': 'L5T 2L2',
#     'city': 'Ontario',
#     'state_code': None,
#     'country_code': 'CAN',
#     'latitude': 43.6455935,
#     'longitude': -79.6944325}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c321'},
#   'name': 'Colibria',
#   'offices': [{'description': 'HQ',
#     'address1': 'Strandveien 15',
#     'address2': 'PO Box 255',
#     'zip_code': '1326',
#     'city': 'Lysaker',
#     'state_code': None,
#     'country_code': 'NOR',
#     'latitude': 59.9115246,
#     'longitude': 10.6389654},
#    {'description': 'UK Office',
#     'address1': 'Abbey House',
#     'address2': '1650 Arlington Business Park',
#     'zip_code': 'RG7 4SA',
#     'city': 'Theale',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Philippines',
#     'address1': '36th Floor Rufino Pacific Tower',
#     'address2': '6784 Ayala Avenue',
#     'zip_code': '1223',
#     'city': 'Makati City',
#     'state_code': None,
#     'country_code': 'PHL',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Spain',
#     'address1': 'Avda. M-40, 15 Bj-7',
#     'address2': 'Pol. Ind. Ventorro del Cano - Edf. Skyline',
#     'zip_code': '28925',
#     'city': 'AlcorcÃ³n (Madrid)',
#     'state_code': None,
#     'country_code': 'ESP',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c329'},
#   'name': 'Kurani Interactive',
#   'offices': [{'description': '',
#     'address1': '25 Bridge Ave.',
#     'address2': '',
#     'zip_code': '07701',
#     'city': 'Red Bank',
#     'state_code': 'NJ',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c37f'},
#   'name': 'Compliance 360',
#   'offices': [{'description': 'Corporate Headquarters',
#     'address1': '1185 Sanctuary Parkway',
#     'address2': 'Suite 250',
#     'zip_code': '30009',
#     'city': 'Alpharetta',
#     'state_code': 'GA',
#     'country_code': 'USA',
#     'latitude': 34.045551,
#     'longitude': -84.311385}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c390'},
#   'name': 'Nexant',
#   'offices': [{'description': 'HQ',
#     'address1': '101 2ND ST STE 1000',
#     'address2': '',
#     'zip_code': '94105-3651',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c39a'},
#   'name': 'Sana Security',
#   'offices': [{'description': 'HQ',
#     'address1': '2121 South El Camino Real',
#     'address2': 'Suite 700',
#     'zip_code': '94403-1855',
#     'city': 'San Mateo',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.54763,
#     'longitude': -122.307887}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c3ac'},
#   'name': 'Mind Drivers',
#   'offices': [{'description': '',
#     'address1': 'The Mill',
#     'address2': '381 Brinton Lake Road',
#     'zip_code': '19373',
#     'city': 'Thornton',
#     'state_code': 'PA',
#     'country_code': 'USA',
#     'latitude': 39.896632,
#     'longitude': -75.531072}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c3b6'},
#   'name': 'PopCap Games',
#   'offices': [{'description': '',
#     'address1': '2401 4th Ave',
#     'address2': 'Suite 810',
#     'zip_code': '98121',
#     'city': 'Seattle',
#     'state_code': 'WA',
#     'country_code': 'USA',
#     'latitude': 47.6161693,
#     'longitude': -122.3451897}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c3c8'},
#   'name': 'Picsearch',
#   'offices': [{'description': 'Stockholm Office',
#     'address1': 'Liljeholmsvagen 30',
#     'address2': '',
#     'zip_code': '11761',
#     'city': 'Stockholm',
#     'state_code': None,
#     'country_code': 'SWE',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c420'},
#   'name': 'One97 Communications',
#   'offices': [{'description': 'Headquarters',
#     'address1': '1st Floor, Devika Tower, Nehru Place',
#     'address2': '',
#     'zip_code': '110 019',
#     'city': 'New Delhi',
#     'state_code': None,
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Corporate Office',
#     'address1': 'B 121, Sector 5',
#     'address2': '',
#     'zip_code': '201 301',
#     'city': 'Noida',
#     'state_code': None,
#     'country_code': 'IND',
#     'latitude': 28.5888843,
#     'longitude': 77.3223915},
#    {'description': 'Regional Office',
#     'address1': 'II Floor, Balammal Building',
#     'address2': 'T Nagar',
#     'zip_code': '600017',
#     'city': 'Chennai',
#     'state_code': None,
#     'country_code': 'IND',
#     'latitude': 13.0364759,
#     'longitude': 80.2292154},
#    {'description': 'Regional Office',
#     'address1': '306, Jaswanti Landmark',
#     'address2': 'LBS Marg, Vikhroli (W)',
#     'zip_code': '400 079',
#     'city': 'Mumbai',
#     'state_code': None,
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Regional Office',
#     'address1': '290, 2nd Floor, 100ft ring road,',
#     'address2': '7th Block, 4th Main, BSK 3rd Stage',
#     'zip_code': '560085',
#     'city': 'Bangalore',
#     'state_code': None,
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c42e'},
#   'name': 'C7 Data Centers',
#   'offices': [{'description': '',
#     'address1': '357 South 670 West',
#     'address2': 'Suite 100',
#     'zip_code': '84042',
#     'city': 'Lindon',
#     'state_code': 'UT',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c43e'},
#   'name': 'Recycleinme',
#   'offices': [{'description': 'Recycleinme',
#     'address1': '4th floor,Adv Dharmaraj Complex,Tamil nadu',
#     'address2': '',
#     'zip_code': '629001',
#     'city': 'Nagercoil',
#     'state_code': None,
#     'country_code': 'IND',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c47a'},
#   'name': 'Moonfruit',
#   'offices': [{'description': 'UK Office',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'London',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c4ce'},
#   'name': 'Goodman Networks',
#   'offices': [{'description': '',
#     'address1': '6400 International Parkway',
#     'address2': 'Suite 1000',
#     'zip_code': '75093',
#     'city': 'Plano',
#     'state_code': 'TX',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c4d2'},
#   'name': 'Telx',
#   'offices': [{'description': '',
#     'address1': '1 State Street',
#     'address2': '21st Floor',
#     'zip_code': '10004',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c4e0'},
#   'name': 'CPower',
#   'offices': [{'description': 'HQ',
#     'address1': '17 State Street',
#     'address2': '19th floor, Suite 1910',
#     'zip_code': '10004',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.756054,
#     'longitude': -73.986951}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c4e7'},
#   'name': 'Radio Systemes Ingenierie',
#   'offices': []},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c4f6'},
#   'name': 'Prepared Response',
#   'offices': [{'description': '',
#     'address1': '5350 Carillon Point',
#     'address2': '',
#     'zip_code': '98033',
#     'city': 'Kirkland',
#     'state_code': 'WA',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c505'},
#   'name': 'Optium',
#   'offices': [{'description': 'HQ',
#     'address1': '200 Precision Road',
#     'address2': '',
#     'zip_code': '19044',
#     'city': 'Horsham',
#     'state_code': 'PA',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c56c'},
#   'name': 'OSA Technologies',
#   'offices': [{'description': 'US Office',
#     'address1': '2001 Gateway Place',
#     'address2': 'Suite 520 West',
#     'zip_code': '95110',
#     'city': 'San Jose',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.3706126,
#     'longitude': -121.9219538},
#    {'description': 'Taiwan Office',
#     'address1': '10th Floor, No 300 , Section 4',
#     'address2': 'Chung Hsiao East Road',
#     'zip_code': '',
#     'city': 'Taipei',
#     'state_code': None,
#     'country_code': 'TWN',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'China Office',
#     'address1': 'Unit 1709, Pidemco Tower',
#     'address2': '318 Fu Zhou Road',
#     'zip_code': '200001',
#     'city': 'Shanghai',
#     'state_code': None,
#     'country_code': 'CHN',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c56e'},
#   'name': 'Sanera',
#   'offices': [{'description': 'US Office',
#     'address1': '370 San Aleso Avenue',
#     'address2': '',
#     'zip_code': '94085',
#     'city': 'Sunnyvale',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.39547,
#     'longitude': -122.02719}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c589'},
#   'name': 'eXMeritus',
#   'offices': [{'description': '',
#     'address1': '11250 Waples Mill Road',
#     'address2': 'Suite 330',
#     'zip_code': '22030',
#     'city': 'Fairfax',
#     'state_code': 'VA',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c5a7'},
#   'name': 'Canevaflor',
#   'offices': [{'description': '',
#     'address1': '13, bd Edmond Michelet',
#     'address2': '69008 LYON',
#     'zip_code': '',
#     'city': '',
#     'state_code': None,
#     'country_code': 'FRA',
#     'latitude': 45.1939977,
#     'longitude': 1.4494329}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c5ba'},
#   'name': 'iomart Group',
#   'offices': [{'description': 'London Office',
#     'address1': '11 - 21 Paul Street',
#     'address2': '',
#     'zip_code': 'EC2A 4JU',
#     'city': 'London',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': 51.5231142,
#     'longitude': -0.0846702},
#    {'description': 'Headquarters',
#     'address1': 'Lister Pavilion',
#     'address2': 'Kelvin Campus',
#     'zip_code': 'G20 0SP',
#     'city': 'Glasgow',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': None,
#     'longitude': None},
#    {'description': 'Manchester Office',
#     'address1': 'Lovell House',
#     'address2': 'Archway',
#     'zip_code': 'M15 5RN',
#     'city': 'Manchester',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': 53.4651665,
#     'longitude': -2.2468554},
#    {'description': 'Maidenhead Office',
#     'address1': 'Spectrum House',
#     'address2': 'Clivemont Road',
#     'zip_code': 'SL6 7FW',
#     'city': 'Maidenhead',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': 51.5288219,
#     'longitude': -0.7253893}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c5f1'},
#   'name': 'Everyday Solutions',
#   'offices': [{'description': 'HQ',
#     'address1': '54 Baker Avenue',
#     'address2': 'Suite 300',
#     'zip_code': '01742',
#     'city': 'Concord',
#     'state_code': 'MA',
#     'country_code': 'USA',
#     'latitude': 42.4623551,
#     'longitude': -71.3797358}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c5f8'},
#   'name': 'NanoBio',
#   'offices': [{'description': '',
#     'address1': '2311 Green Road',
#     'address2': 'Suite A',
#     'zip_code': '48105',
#     'city': 'Ann Arbor',
#     'state_code': 'MI',
#     'country_code': 'USA',
#     'latitude': 42.3079711,
#     'longitude': -83.6927623}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c610'},
#   'name': 'PaymentOne',
#   'offices': [{'description': '',
#     'address1': '5883 Rue Ferrari',
#     'address2': '',
#     'zip_code': '95138',
#     'city': 'San Jose',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.248043,
#     'longitude': -121.776935}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c618'},
#   'name': 'optionsXpress',
#   'offices': [{'description': '',
#     'address1': '311 West Monroe Street',
#     'address2': 'Suite 1000',
#     'zip_code': '60606',
#     'city': 'Chicago',
#     'state_code': 'IL',
#     'country_code': 'USA',
#     'latitude': 41.8806258,
#     'longitude': -87.6356066}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c619'},
#   'name': 'Skywire Software',
#   'offices': [{'description': 'HQ',
#     'address1': '2401 Internet Boulevard',
#     'address2': 'Suite 201',
#     'zip_code': '75034',
#     'city': 'Frisco',
#     'state_code': 'TX',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c63f'},
#   'name': 'Sirific Wireless',
#   'offices': [{'description': 'HQ',
#     'address1': '740 East Campbell Road',
#     'address2': 'Suite 300',
#     'zip_code': '75081',
#     'city': 'Richardson',
#     'state_code': 'TX',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c659'},
#   'name': 'LogicLibrary',
#   'offices': [{'description': 'HQ',
#     'address1': '100 West Station Square Drive',
#     'address2': 'Suite 1900',
#     'zip_code': '15219-1122',
#     'city': 'Pittsburgh',
#     'state_code': 'PA',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c6ab'},
#   'name': 'Vigilos',
#   'offices': [{'description': 'Headquarters',
#     'address1': '2030 First Avenue, Ste 300',
#     'address2': '',
#     'zip_code': '98121',
#     'city': 'Seattle',
#     'state_code': 'WA',
#     'country_code': 'USA',
#     'latitude': 47.6113314,
#     'longitude': -122.3430581}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c6c0'},
#   'name': 'Block Shield',
#   'offices': [{'description': '',
#     'address1': '190 Strand',
#     'address2': '',
#     'zip_code': 'WC2R 1JN',
#     'city': 'London',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': 51.5127901,
#     'longitude': -0.114374}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c6d0'},
#   'name': 'Netrake',
#   'offices': [{'description': 'HQ',
#     'address1': '3000 Technology Drive',
#     'address2': 'Suite 100',
#     'zip_code': '75074',
#     'city': 'Plano',
#     'state_code': 'TX',
#     'country_code': 'USA',
#     'latitude': None,
#     'longitude': None}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c6ee'},
#   'name': 'EnterSys Group',
#   'offices': [{'description': '',
#     'address1': '13280 NW Freeway',
#     'address2': 'Suite F-100',
#     'zip_code': '77040',
#     'city': 'Houston',
#     'state_code': 'TX',
#     'country_code': 'USA',
#     'latitude': 29.8487788,
#     'longitude': -95.5045451}]},
#  {'_id': {'$oid': '52cdef7f4bab8bd67529c6fa'},
#   'name': 'EnteGreat',
#   'offices': [{'description': '',
#     'address1': '1900 International Park Drive',
#     'address2': 'Suite 200',
#     'zip_code': '35243-4204',
#     'city': 'Birmingham',
#     'state_code': 'AL',
#     'country_code': 'USA',
#     'latitude': 33.4077856,
#     'longitude': -86.7613019}]}]
